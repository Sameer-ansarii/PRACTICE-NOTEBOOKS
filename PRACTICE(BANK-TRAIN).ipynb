# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bank_train - bank_train.csv")
df.sample(5)
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 486    20        47         2    999         0          -1.8          93.075
# 701    36       155        11    999         0           1.4          93.444
# 2234   38       177         3    999         0           1.1          93.994
# 903    31       115         2    999         0          -2.9          92.201
# 456    52       167         1     10         4          -2.9          92.201
#
#       cons.conf.idx  euribor3m  nr.employed  ...  job  marital  education  \
# 486           -47.1      1.405       5099.1  ...    8        2          7
# 701           -36.1      4.964       5228.1  ...    0        1          6
# 2234          -36.4      4.857       5191.0  ...    1        1          1
# 903           -31.4      0.883       5076.2  ...    0        2          6
# 456           -31.4      0.883       5076.2  ...    4        1          3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3295 entries, 0 to 3294
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             3295 non-null   int64
#  1   duration        3295 non-null   int64
#  2   campaign        3295 non-null   int64
#  3   pdays           3295 non-null   int64
#  4   previous        3295 non-null   int64
#  5   emp.var.rate    3295 non-null   float64
#  6   cons.price.idx  3295 non-null   float64
#  7   cons.conf.idx   3295 non-null   float64
#  8   euribor3m       3295 non-null   float64
#  9   nr.employed     3295 non-null   float64
#  10  purchased       3295 non-null   int64
#  11  id              3295 non-null   int64
#  12  job             3295 non-null   int64
#  13  marital         3295 non-null   int64
#  14  education       3295 non-null   int64
#  15  default         3295 non-null   int64
#  16  housing         3295 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# duration          0
# campaign          0
# pdays             0
# previous          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# purchased         0
# id                0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# poutcome          0
# dtype: int64

# %%
a = pd.DataFrame(data=[df.isna().sum().tolist(), ["{:.2f}".format(i)+'%' \
           for i in (df.isna().sum()/df.shape[0]*100).tolist()]], 
           columns=df.columns, index=['NA Count', 'NA Percent']).transpose()

a.style.background_gradient(cmap="Pastel1_r", subset=['NA Count'])
# Out:
# <style type="text/css">
# #T_b1a2f_row0_col0, #T_b1a2f_row1_col0, #T_b1a2f_row2_col0, #T_b1a2f_row3_col0, #T_b1a2f_row4_col0, #T_b1a2f_row5_col0, #T_b1a2f_row6_col0, #T_b1a2f_row7_col0, #T_b1a2f_row8_col0, #T_b1a2f_row9_col0, #T_b1a2f_row10_col0, #T_b1a2f_row11_col0, #T_b1a2f_row12_col0, #T_b1a2f_row13_col0, #T_b1a2f_row14_col0, #T_b1a2f_row15_col0, #T_b1a2f_row16_col0, #T_b1a2f_row17_col0, #T_b1a2f_row18_col0, #T_b1a2f_row19_col0, #T_b1a2f_row20_col0, #T_b1a2f_row21_col0 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# </style>
# <table id="T_b1a2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1a2f_level0_col0" class="col_heading level0 col0" >NA Count</th>
#       <th id="T_b1a2f_level0_col1" class="col_heading level0 col1" >NA Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1a2f_level0_row0" class="row_heading level0 row0" >age</th>
# ...

# %%
for col in df.columns:
    print(col,':',len(df[col].unique()),'labels')
# Out:
# age : 65 labels
# duration : 760 labels
# campaign : 24 labels
# pdays : 20 labels
# previous : 7 labels
# emp.var.rate : 10 labels
# cons.price.idx : 26 labels
# cons.conf.idx : 26 labels
# euribor3m : 216 labels
# nr.employed : 11 labels
# purchased : 2 labels
# id : 3295 labels
# job : 12 labels
# marital : 4 labels
# education : 8 labels
# default : 3 labels
# housing : 3 labels
# loan : 3 labels
# contact : 2 labels
# month : 10 labels
# day_of_week : 5 labels
# poutcome : 3 labels

# %%
df.columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'purchased', 'id', 'job', 'marital', 'education', 'default', 'housing',
#        'loan', 'contact', 'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (3295, 22)

# %% [markdown]
# ## Data is no null values and no categorical column so we detect outliers  now

# %%
plt.subplot(1,2,1)
sns.boxplot(y='age',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='duration',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='campaign',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='pdays',data=df)
plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='previous',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='emp.var.rate',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='cons.price.idx',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='cons.conf.idx',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='euribor3m',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='nr.employed',data=df)

plt.show()

# %%
plt.subplot(2,2,1)
sns.boxplot(y='purchased',data=df)

plt.subplot(2,2,2)
sns.boxplot(y='id',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='job',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='marital',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='education',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='default',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='housing',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='loan',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='contact',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='month',data=df)

plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(y='day_of_week',data=df)

plt.subplot(1,2,2)
sns.boxplot(y='poutcome',data=df)

plt.show()

# %% [markdown]
# # We detect and drop the outliers of 'duration' column

# %%
df.duration.describe()
# Out:
# count    3295.000000
# mean      255.339302
# std       252.303834
# min         0.000000
# 25%       102.500000
# 50%       180.000000
# 75%       314.500000
# max      3643.000000
# Name: duration, dtype: float64

# %%
df.duration.quantile(0)
# Out:
# 0.0

# %%
df.duration.quantile(0.25,interpolation="higher")
# Out:
# 103

# %%
df.duration.quantile(0.5,interpolation="higher")
# Out:
# 180

# %%
df.duration.quantile(0.75,interpolation="higher")
# Out:
# 315

# %%
df.duration.quantile(1,interpolation="higher")
# Out:
# 3643

# %%
percentile_99 = df.duration.quantile(0.99)
percentile_99
# Out:
# 1186.2399999999998

# %%
df[df.duration>percentile_99]
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 84     47      2653         3    999         0           1.4          94.465
# 95     34      1190         2    999         0          -1.8          92.893
# 108    49      1980         2    999         0           1.1          93.994
# 316    43      1332         1    999         0           1.4          93.444
# 330    43      1806         4    999         0           1.4          93.918
# 394    26      1447         2    999         0          -1.8          92.843
# 441    58      1234         3    999         0           1.1          93.994
# 443    35      1259         6    999         0           1.4          93.918
# 447    47      1334         1    999         0           1.1          93.994
# 510    59      1438         2    999         0           1.1          93.994
# 547    54      1868         2     10         1          -1.1          94.767
# ...

# %%
df.drop(index=[3225,3098,3081,3078,3002,2895,2447,2441,2387,2304,2190,2070,1761,1591,1431,1299,],inplace=True)

# %%
df[df.duration>percentile_99]
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 84     47      2653         3    999         0           1.4          94.465
# 95     34      1190         2    999         0          -1.8          92.893
# 108    49      1980         2    999         0           1.1          93.994
# 316    43      1332         1    999         0           1.4          93.444
# 330    43      1806         4    999         0           1.4          93.918
# 394    26      1447         2    999         0          -1.8          92.843
# 441    58      1234         3    999         0           1.1          93.994
# 443    35      1259         6    999         0           1.4          93.918
# 447    47      1334         1    999         0           1.1          93.994
# 510    59      1438         2    999         0           1.1          93.994
# 547    54      1868         2     10         1          -1.1          94.767
# ...

# %%
df.drop(index=[84,95,108,316,330,394,441,443,447,510,547,818,977,1008,1090,1144,1197],inplace=True)

# %%
df[df.duration>percentile_99]
# Out:
# Empty DataFrame
# Columns: [age, duration, campaign, pdays, previous, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, purchased, id, job, marital, education, default, housing, loan, contact, month, day_of_week, poutcome]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# # As you see all the outliers are removed so next step is to standarize data

# %%
df.columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'purchased', 'id', 'job', 'marital', 'education', 'default', 'housing',
#        'loan', 'contact', 'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (3262, 22)

# %%
X = df.drop(['id','purchased'], axis=1)

X.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   49       284         1    999         0           1.4          93.918
# 1   58       374         1    999         0           1.4          93.918
# 2   36       529         1    999         0           1.4          93.444
# 3   47       216         1    999         0           1.4          94.465
# 4   38       191         1    999         0          -1.8          92.893
#
#    cons.conf.idx  euribor3m  nr.employed  job  marital  education  default  \
# 0          -42.7      4.957       5228.1    1        0          7        1
# 1          -42.7      4.963       5228.1    5        1          0        1
# 2          -36.1      4.965       5228.1    0        3          6        0
# 3          -41.8      4.961       5228.1    4        1          0        0
# 4          -46.2      1.313       5099.1    0        2          7        0
#
#    housing  loan  contact  month  day_of_week  poutcome
# ...

# %%
y = df['purchased']

y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: purchased, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train[['age','duration','pdays','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']] = scaler.fit_transform(X_train
     [['age','duration','pdays','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']])

X_train.head()
# Out:
#            age  duration  campaign     pdays  previous  emp.var.rate  \
# 3294 -1.153026 -0.670287         2  0.199039         0           1.1
# 1386  0.589296 -0.650954        11  0.199039         0           1.1
# 829  -1.249822  4.496623         1  0.199039         0           1.1
# 2807 -0.862639 -0.771789         1  0.199039         1          -1.8
# 2352 -0.669048  0.615399         5  0.199039         0           1.1
#
#       cons.price.idx  cons.conf.idx  euribor3m  nr.employed  job  marital  \
# 3294        0.721218       0.884530   0.709207     0.330735    1        2
# 1386        0.721218       0.884530   0.709787     0.330735    2        1
# 829         0.721218       0.884530   0.708047     0.330735    1        1
# 2807       -1.184074      -1.247273  -1.364234    -0.934058    0        2
# 2352        0.721218       0.884530   0.709207     0.330735    6        1
#
#       education  default  housing  loan  contact  month  day_of_week  poutcome
# ...
