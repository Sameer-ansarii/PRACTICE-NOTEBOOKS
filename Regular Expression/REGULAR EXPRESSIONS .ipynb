# %% [markdown]
# ### What is Regular Expression?
#
# * A regular expression, also known as regex, is a special sequence of characters that defines a search pattern to find a string or set of strings, such as a word or a sentence.
#
#
# * Regular expression is a search pattern.
#
#
# * It can be used to detect the presence or absence of a text by a given search pattern, and it can detect one or more search patterns.
#
#
# * After detecting the pattern, regular expressions can also replace or manipulate the matched strings based on the given pattern, as well as split the text into one or more subpatterns.
#
#
# * A regular expression is a pattern of characters that is used to match and manipulate text. It is a sequence of characters and metacharacters that represent a set of rules to match one or more strings of text.

# %% [markdown]
# ### How to use regular expression in python
#
#
# * 're' is a in-built Python library which is used to work with regular expressions.
#
#
# * To use regular expressions in Python, you first need to import the re module.

# %% [markdown]
# ### Use of Regular Expression
#
#
# * Search and replace: You can use regular expressions to search for a pattern in a string and replace it with another string.
#
#
# * Text validation: Regular expressions can be used to validate whether a given string conforms to a specific pattern or format. For example, you could use regular expressions to check whether an email address or phone number is formatted correctly.
#
#
# * Data extraction / Web Scrapping: You can use regular expressions to extract specific data from a larger body of text. For example, you could use regular expressions to extract all of the URLs from an HTML file or you can extract a specific thing from a website.
#
#
# * Parsing and tokenization: Regular expressions can be used to break a string down into smaller pieces or tokens, based on specific patterns or delimiters.
#
#
# * Cleaning and preprocessing: Regular expressions can be used to clean and preprocess text data, such as removing unwanted characters or formatting, before further analysis.
#
#
# * File handling: Regular expressions can be used to search for patterns within a file, such as finding all instances of a specific word or phrase within a text document.

# %% [markdown]
# ### Meta Characters used in Regular Expression

# %% [markdown]
# ![12234737_be2bb558-a9dc-4977-9243-8b790f75fc92_lg.webp](attachment:12234737_be2bb558-a9dc-4977-9243-8b790f75fc92_lg.webp)

# %% [raw]
# . (dot): Matches any single character except newline.
#
# ^ (caret): Matches the start of the string.
#
# $ (dollar sign): Matches the end of the string.
#
# * (asterisk): Matches zero or more occurrences of the preceding character or group.
#
# + (plus): Matches one or more occurrences of the preceding character or group.
#
# ? (question mark): Matches zero or one occurrence of the preceding character or group.
#
# | (vertical bar): Matches either the expression before or after the vertical bar.
#
# [] (square brackets): Matches any single character that is in the specified set of characters.
#
# [^] (caret within square brackets): Matches any single character that is not in the specified set of characters.
#
# () (parentheses): Groups a sequence of characters together and creates a capture group.
#
# {} (curly braces): Matches a specified number of occurrences of the preceding character or group.
#
# \ (backslash): Escapes the following character, allowing it to be used as a literal character.

# %% [raw]
# ## Quantifiers:- '*', '+', '?', '{ }'
#
# 1) '*' - Matches zero or more occurrences of the preceding character or group. For example, a* matches zero or more occurrences of the character 'a'.
#
# 2) '+' - Matches one or more occurrences of the preceding character or group. For example, a+ matches one or more occurrences of the character 'a'.
#
# 3) '?' - Matches zero or one occurrence of the preceding character or group. For example, a? matches zero or one occurrence of the character 'a'.
#
# 4) {m} - Matches exactly m occurrences of the preceding character or group. For example, a{3} matches exactly three occurrences of the character 'a'.
#
# 5) {m,n} - Matches between m and n occurrences of the preceding character or group. For example, a{2,4} matches between two and four occurrences of the character 'a'.
#
#
# ## Anchors: '^', '$', '\b'
#
# 1) '^' - Matches the start of the string. For example, ^a matches any string that starts with the character 'a'.
#
# 2) '$' - Matches the end of the string. For example, a$ matches any string that ends with the character 'a'.
#
# 3) '\b' - Matches a word boundary. For example, \bcat\b matches the word 'cat' when it is a separate word and not part of a larger word.
#
#
# ## Wildcard: '.'
#
# 1) '.' - Matches any character except a newline character. For example, a. matches any string that starts with 'a' followed by any character.

# %% [markdown]
# ### Functions in Regex
#
#
# * The re library in Python provides functions for working with regular expressions.
#
#
# 1) re.search(pattern, string, flags=0): Searches the string for the first occurrence of the pattern, and returns a Match object if found. If not found, returns None.
#
#
# 2) re.compile(pattern, flags=0): Compiles a regular expression pattern into a regular expression object, which can then be used to match strings.
#
#
# 3) re.match(pattern, string, flags=0): Matches the pattern at the beginning of the string, and returns a Match object if found. If not found, returns None.
#
#
# 4) re.findall(pattern, string, flags=0): Finds all non-overlapping occurrences of the pattern in the string, and returns them as a list of strings.
#
#
# 5) re.sub(pattern, repl, string, count=0, flags=0): Replaces all occurrences of the pattern in the string with the replacement string repl, and returns the modified string.
#
#
# 6) re.split(pattern, string, maxsplit=0, flags=0): Splits the string at all occurrences of the pattern, and returns the parts as a list of strings.
#
#
# 7) re.finditer(pattern, string, flags=0): Returns an iterator that yields Match objects for each non-overlapping occurrence of the pattern in the string.

# %% [markdown]
# ### Import the Regex Library in python

# %%
import re

# %% [markdown]
# ### re.search(pattern, string, flags=0)
#
# * Searches the string with the matching pattern. Returns a Match object if found. If not found, returns None.
#
#
# * In a string if pattern matches many times it will return only first occurance of the matched pattern.
#
#
# * It is used to find that pattern is present in a string or not?
#
#
# * After finding the pattern in a string it will give the index location.

# %%
re.search(r'sameer', 'sameer sameer sameer jhchc ahascja askjasscks sjosjk')
# Out:
# <re.Match object; span=(0, 6), match='sameer'>

# %%
re.search(r'sameer', 'sam sam sam') # if the pattern is not matched it will return nothing.

# %%
# print output of re.search()

match = re.search('sameer', 'sameer sameer sameer jhchc ahascja askjas')
print(match.group())
# Out:
# sameer

# %% [markdown]
# ### re.findall(pattern, string, flags=0)
#
#
# * Use to find a pattern in a string. Returns a list of string with matched pattern, if pattern is found. Returns a empty list if pattern is not found.
#
#
# * In a string if pattern matches many times it will return all occurances of the matched pattern in a list of strings.
#
#
# * It is used to find a pattern.

# %%
re.findall(r'sameer', 'sameer sameer sameer sam jhchc sam ahascja askjasscks sjosjk')
# Out:
# ['sameer', 'sameer', 'sameer']

# %%
# print output of re.findall()

match = re.findall(r'sameer', 'sameer sameer sameer jhchc ahascja askjas')
print(match)
# Out:
# ['sameer', 'sameer', 'sameer']

# %% [markdown]
# # Use of Meta Characters

# %%
a = "charlie and the chocolate factory"

b = "asameer130@gmail.com"

c = "hello"

d = "xyz, yz, xyzz, xxzzy, zyz, xxyz"

# %%
# If we search a string which contains '.' (dot) like email address or url than we can't find it by given '.' in pattern.
# It will return the first letter of the string.

match = re.search(r'.',b)  
print(match)
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %% [markdown]
# ### Use of \ (backslash) : Escapes special characters, allowing them to be treated as literal characters.
#
# * It is used to drop special meaning of characters following it.
#
#
# * It will return the string with matched pattern along with the index location of the string. Return none if pattern is not found.

# %%
match = re.search(r'\.',b)  
print(match)
# Out:
# <re.Match object; span=(16, 17), match='.'>

# %%
match = re.search(r'\.c',b)  
print(match)
# Out:
# <re.Match object; span=(16, 18), match='.c'>

# %%
match = re.search(r'\.ca',b)  
print(match)
# Out:
# None

# %%
pattern = r'\d{3}-\d{2}-\d{4}' # Matches a social security number in the format XXX-XX-XXXX
text = 'John Doe: 123-45-6789'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['123-45-6789']

# %% [markdown]
# ### Use of [ ] (square brakets)
#
# * Matches any single character inside the brackets.
#
#
# * They're used to specifying a character class, which is a set of characters.

# %%
pattern = r'[aeiou]'
text = 'apple, orange, grape'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['a', 'e', 'o', 'a', 'e', 'a', 'e']

# %%
match = re.search(r'[.]',b)  
print(match)
# Out:
# <re.Match object; span=(16, 17), match='.'>

# %%
match = re.findall(r'[a]',b)  
print(match)
# Out:
# ['a', 'a', 'a']

# %%
match = re.search(r'[hel]',c)  
print(match)
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
match = re.findall(r'[hel]',c)  
print(match)
# Out:
# ['h', 'e', 'l', 'l']

# %%
match = re.search(r'[a-l]',c)  
print(match)
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
match = re.findall(r'[a-l]',c)  
print(match)
# Out:
# ['h', 'e', 'l', 'l']

# %%
match = re.findall(r'[a-l]','bar jguyuy jhuiu kihiho')  
print(match)
# Out:
# ['b', 'a', 'j', 'g', 'j', 'h', 'i', 'k', 'i', 'h', 'i', 'h']

# %%
match = re.findall(r'[0-5]','655466127')  
print(match)
# Out:
# ['5', '5', '4', '1', '2']

# %% [markdown]
# ### Use of [^] (caret within square brackets): Matches any single character that is not in the specified set of characters.

# %%
# If we use caret in square brackets means don't search for given pattern and returns everything except given pattern.

match = re.findall('[^a-l]',c)  
print(match)
# Out:
# ['o']

# %%
match = re.findall('[^a]','sameer')  # Return everything except 'a'
print(match)
# Out:
# ['s', 'm', 'e', 'e', 'r']

# %%
match = re.findall('[^a|e]','sameer ameer air')  # Return everything except 'a'
print(match)
# Out:
# ['s', 'm', 'r', ' ', 'm', 'r', ' ', 'i', 'r']

# %% [markdown]
# ### Use of ^ (caret)
#
#
# * Matches the beginning of a string..
#
#
# * It is used to search a srting which starts with a specific word.
#
#
# * It is only used to search the beginning of a string.

# %%
pattern = r'^Hello'
text = 'Hello, world!'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['Hello']

# %%
pattern = r'^world'
text = 'Hello, world!'
matches = re.findall(pattern, text)
print(matches)
# Out:
# []

# %%
match = re.search('^c',a)  
print(match)
# Out:
# <re.Match object; span=(0, 1), match='c'>

# %%
match = re.search('^a',a)  
print(match)
# Out:
# None

# %%
match = re.findall('^c',a)  
print(match)
# Out:
# ['c']

# %%
match = re.search('^s','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# <re.Match object; span=(0, 1), match='s'>

# %%
match = re.findall('^f','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# []

# %%
match = re.findall('^ss','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# []

# %% [markdown]
# ### Use of  '.'  (dot)
#
#
# * It maches any character except newline.

# %%
match = re.search('f.','sameer sf5af ckljkd ss sf5n')  
print(match)
# Out:
# <re.Match object; span=(8, 10), match='f5'>

# %%
match = re.search('f..','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# <re.Match object; span=(7, 10), match='faf'>

# %%
match = re.findall('s..','sameer faf cklshjkd ss sfan')  
print(match)
# Out:
# ['sam', 'shj', 'ss ', 'sfa']

# %%
match = re.findall('s.m','sameer faf ckljkd ss sfan sum shm')  
print(match)
# Out:
# ['sam', 'sum', 'shm']

# %%
pattern = r'f..t'
text = 'foot, fight, fruit'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['foot']

# %% [markdown]
# ### Use of $ (Dollar)
#
#
# * Matches the end of a string.
#
#
# * It is used to search a srting which end with a specific word or character.
#
#
# * It is only used to search the end of a string.

# %%
pattern = r'world!$'
text = 'Hello, world!'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['world!']

# %%
pattern = r'Hello$'
text = 'Hello, world!'
matches = re.findall(pattern, text)
print(matches)
# Out:
# []

# %%
match = re.search('s$','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# None

# %%
match = re.search('n$','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# <re.Match object; span=(24, 25), match='n'>

# %%
match = re.search('an$','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# <re.Match object; span=(23, 25), match='an'>

# %%
match = re.findall('an$','sameer an faf ckljkd ss sfan')  
print(match)
# Out:
# ['an']

# %% [markdown]
# ### Use of | (vertical bar) : Matches either the expression before or after the |
#
#
# * It means OR, such as condition.
#
#
# * Matches either the expression before or after the vertical bar. i.e "(com|in|org)".
#
#
# * In a single regex we can search for multiple patterns by using | also i.e "^.*.xml$|^.*.jar$|^.*.exe$".
#
#
# * It is used to find the characters in between words.

# %%
pattern = r'Hello|Hi'
text = 'Hello, world! Hi, there.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['Hello', 'Hi']

# %%
match = re.findall('sa|fa|c','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# ['sa', 'fa', 'c', 'fa']

# %%
match = re.findall('sa|so','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# ['sa']

# %%
match = re.findall('sa|lj','sameer faf ckljkd ss sfan')  
print(match)
# Out:
# ['sa', 'lj']

# %% [markdown]
# ### Use of '?' (Question Mark)
#
#
# *  Matches zero or one occurrence.
#
#
# * It tells that whether a pattern is present or absent.

# %%
pattern = r'colou?r'
text = 'color, colour, colouur'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['color', 'colour']

# %%
match = re.findall('ab?','a, ab, abbbb')  
print(match)
# Out:
# ['a', 'ab', 'ab']

# %%
match = re.findall('sam?','jjsammmm.,.,mm hdhdhdsaammmmmjdjsamdjsamhdhhdsam')  
print(match)
# Out:
# ['sam', 'sa', 'sam', 'sam', 'sam']

# %%
match = re.findall('s|a|m?','a s m sam jjsammmm.,.,mm hdhdhdsaammmmmjdjsamdjsamhdhhdsam')  
print(match)
# Out:
# ['a', '', 's', '', 'm', '', 's', 'a', 'm', '', '', '', 's', 'a', 'm', 'm', 'm', 'm', '', '', '', '', 'm', 'm', '', '', '', '', '', '', '', 's', 'a', 'a', 'm', 'm', 'm', 'm', 'm', '', '', '', 's', 'a', 'm', '', '', 's', 'a', 'm', '', '', '', '', '', 's', 'a', 'm', '']

# %%
match = re.findall('ab?','abc')  
print(match)
# Out:
# ['ab']

# %%
match = re.findall('ab?','aaaaabbbbbbbbbc')  
print(match)
# Out:
# ['a', 'a', 'a', 'a', 'ab']

# %%
match = re.findall('a?b','abbbbbbbbbc aaaab')  
print(match)
# Out:
# ['ab', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'ab']

# %%
match = re.findall('b?','abbbbbbbbbc')  
print(match)
# Out:
# ['', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', '', '']

# %%
match = re.findall('bb?','abbbbbbbbbc')  
print(match)
# Out:
# ['bb', 'bb', 'bb', 'bb', 'b']

# %%
match = re.findall('b?b','abbbbbbbbbc')  
print(match)
# Out:
# ['bb', 'bb', 'bb', 'bb', 'b']

# %%
match = re.findall('sa?','sameer sam sar sad sag')  
print(match)
# Out:
# ['sa', 'sa', 'sa', 'sa', 'sa']

# %%
match = re.findall('sa?','ssssasasa samsa sarsa sadsa sagsa')  
print(match)
# Out:
# ['s', 's', 's', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa']

# %%
match = re.findall('sa?s','sasasasasssss')  # 'sa' 1 baar ho 's' bhi 1 baar ho
print(match)
# Out:
# ['sas', 'sas', 'ss', 'ss']

# %%
match = re.findall('sa?','sasasa samsasa00 sarsasasa00 sadsa sagsa')  
print(match)
# Out:
# ['sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa']

# %% [markdown]
# ### Use of * (asterisk)
#
#
# * Matches zero or more occurrences of the preceding character or group.
#
#
# * It will return the first letter of pattern and the whole pattern.

# %%
# 'g' se starting ho, 'o' zero ya kitni bhi baar aaye or ending 'd' pe ho

pattern = r'go*d'
text = 'gd, god, good, goood'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['gd', 'god', 'good', 'goood']

# %%
match = re.findall('sa*','saaasasa samsasa00 sarsasasa00 sadsa sagsa')  
print(match)
# Out:
# ['saaa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa', 'sa']

# %%
match = re.findall('sa*','sun sameer')  
print(match)
# Out:
# ['s', 'sa']

# %%
match = re.findall('ab*','aaaabbbcaaaab sameer aaabbb')  
print(match)
# Out:
# ['a', 'a', 'a', 'abbb', 'a', 'a', 'a', 'ab', 'a', 'a', 'a', 'abbb']

# %%
match = re.findall('ab*','abbbc abbbbb bbb')  
print(match)
# Out:
# ['abbb', 'abbbbb']

# %%
match = re.findall('ab*','abbbcbbabc a a a') 
print(match)
# Out:
# ['abbb', 'ab', 'a', 'a', 'a']

# %%
match = re.findall('a*b','aaaabbbcbbabc  aaabbbbb') # 'a' kitni bhi baar ho par 'b' bs 1 baar ho.
print(match)
# Out:
# ['aaaab', 'b', 'b', 'b', 'b', 'ab', 'aaab', 'b', 'b', 'b', 'b']

# %% [markdown]
# ### Use of + (plus)
#
#
# * Matches one or more occurrences of the preceding character or group.

# %%
# Starting 'g' se ho 'o' 1 baar ya zyada baar aaye 'd' pe ending ho

pattern = r'go+d'
text = 'gd, god, good, goood'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['god', 'good', 'goood']

# %%
match = re.findall('x+','xxxxxxjxxxx hdhdhxjje')  # 'x' kitni bhi baar repeat ho skta hai
print(match)
# Out:
# ['xxxxxx', 'xxxx', 'x']

# %%
match = re.findall('x+s','xxxxxsss') # 'x' kitni hi baar repeat ho or uske baad 's' aaye
print(match)
# Out:
# ['xxxxxs']

# %%
match = re.findall('x+a','xxxxxs') # 'x' kitni hi baar repeat ho or uske baad 'a' aaye 
print(match)
# Out:
# []

# %% [markdown]
# ### Use of {} (curly braces)
#
# * {n}: Matches exactly n occurrences of the preceding character or group.
#
#
# * Matches a specified number of occurrences

# %%
pattern = r'go{2}d'
text = 'gd, god, good, goood'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['good']

# %%
pattern = r'go{2,3}d'
text = 'gd, god, good, goood, goooood'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['good', 'goood']

# %%
match = re.findall('x{2,4}','xxxxxs jjjxx xcx ksksksxxx gggxj') # jaha pe 'x' 2 se 4 baar aaya hai vo output dega
print(match)
# Out:
# ['xxxx', 'xx', 'xxx']

# %% [markdown]
# ### Use of () (parentheses) : Groups multiple subexpressions into a single expression.
#
# * Enclose a group of regex.
#
#
# * Groups a sequence of characters together and creates a capture group.

# %%
# 'foo' or 'bar' jaha pe ho return do. Chahe word ke starting me ho, beech me ho ya ending me ho.

pattern = r'(foo|bar)'
text = 'foofoofoo, foobar, barfoobar'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['foo', 'foo', 'foo', 'foo', 'bar', 'bar', 'foo', 'bar']

# %%
# jaha pe 'f' ho uske baad 'o' 1 ya 1 se zyada baar ho return karo

pattern = r'(fo)+'
text = 'foot, bfoot, bfooooooob'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['fo', 'fo', 'fo']

# %%
match = re.findall('(x|y)','xxxxxs jjjxx yx xcx ksksksxxx') # jaha pe 'x' ya 'y' hai vo output dega
print(match)
# Out:
# ['x', 'x', 'x', 'x', 'x', 'x', 'x', 'y', 'x', 'x', 'x', 'x', 'x', 'x']

# %%
match = re.findall('(a|b)','abc bbc cbbba') # jaha pe 'a' or 'b' hai output dega
print(match)
# Out:
# ['a', 'b', 'b', 'b', 'b', 'b', 'b', 'a']

# %%
match = re.findall('(a|b)c','abc bbc cbbba bccc bn ac bg') # jaha pe 'a' ya 'b' hai or uske baad c hai vo output dega
print(match)
# Out:
# ['b', 'b', 'b', 'a']

# %% [markdown]
# # Character Sets / Regex Sets
#
#
# * It is a set of characters inside a pair of square brackets [ ] with a special meaning.

# %% [markdown]
# ![WhatsApp%20Image%202023-05-06%20at%2015.25.35.jpg](attachment:WhatsApp%20Image%202023-05-06%20at%2015.25.35.jpg)

# %% [markdown]
# * [arn] = Returns a match where one of the specified characters (a, r, or n) are present
#
#
# * [a-n] = Returns a match for any lower case character, alphabetically between a and n
#
#
# * [^arn] = Returns a match for any character EXCEPT a, r, and n
#
#
# * [0123] = Returns a match where any of the specified digits (0, 1, 2, or 3) are present
#
#
# * [0-9] = Returns a match for any digit between 0 and 9
#
#
# * [0-5][0-9] = Returns a match for any two-digit numbers from 00 and 59
#
#
# * [a-zA-Z] = Returns a match for any character alphabetically between a and z, lower case OR upper case
#
#
# * [+] = In sets, +, *, ., |, (), $,{} has no special meaning, so [+] means: return a match for any + character in the string

# %%
pattern = r'[arn]'
text = 'The rat in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['r', 'a', 'n', 'a']

# %%
pattern = r'[a-n]'
text = 'The rat in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['h', 'e', 'a', 'i', 'n', 'h', 'e', 'h', 'a']

# %%
pattern = r'[^a-n]'
text = 'The rat in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['T', ' ', 'r', 't', ' ', ' ', 't', ' ', 't', '.']

# %%
pattern = r'[0123]'
text = 'The rat in the hat 987135286.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['1', '3', '2']

# %%
pattern = r'[^0123]'
text = 'The rat in the hat 987135286.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['T', 'h', 'e', ' ', 'r', 'a', 't', ' ', 'i', 'n', ' ', 't', 'h', 'e', ' ', 'h', 'a', 't', ' ', '9', '8', '7', '5', '8', '6', '.']

# %%
pattern = r'[0-9]'
text = 'The rat in the hat 987135286.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['9', '8', '7', '1', '3', '5', '2', '8', '6']

# %%
# first digit '0' se '4' ke beech me ho or last digit '0' se '8' ke beech me ho. i.e 0-48

pattern = r'[0-4][0-8]'
text = 'The rat in the hat 987135286.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['13', '28']

# %%
pattern = r'[a-zA-Z]'
text = 'The rat in the Hat 6464.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['T', 'h', 'e', 'r', 'a', 't', 'i', 'n', 't', 'h', 'e', 'H', 'a', 't']

# %%
pattern = r'[.]'
text = 'asameer130@gmail.com'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['.']

# %%
pattern = r'.'
text = 'asameer130@gmail.com'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['a', 's', 'a', 'm', 'e', 'e', 'r', '1', '3', '0', '@', 'g', 'm', 'a', 'i', 'l', '.', 'c', 'o', 'm']

# %% [markdown]
# # Special Sequence in Regex
#
#
# * In Python regular expressions, a "special sequence" refers to a backslash \ followed by a character that has a special meaning in the regular expression syntax. These special sequences are used to match specific types of characters or to represent special characters that cannot be matched directly.
#
#
# * It makes easier to write a commonly used pattern.

# %% [raw]
# \A: Matches if the string begins with the given character.
#
# \d: Matches any decimal digit character (equivalent to [0-9]).
#
# \D: Matches any non-digit character (equivalent to [^0-9]).
#
# \d+: Matches one or more decimal digits. For example, the regex pattern "\d+" would match any string with one or more digits.
#
# \w: Matches any alphanumeric character (equivalent to [a-zA-Z0-9_]).
#
# \W: Matches any non-alphanumeric character (equivalent to [^a-zA-Z0-9_]).
#
# \s: Matches any whitespace character (equivalent to [ \t\n\r\f\v]).
#
# \S: Matches any non-whitespace character (equivalent to [^ \t\n\r\f\v]).
#
# \b: Matches a word boundary (the position between a word character and a non-word character).
#
# \B: Matches a non-word boundary.
#
# \n: Matches a newline character.
#
# \t: Matches a tab character.
#
# \Z: Matches if the string ends with the given regex.

# %% [markdown]
# # Use of Special Sequences

# %%
a = "Harry Potter"

# %% [markdown]
# ### \A: Matches if the string begins with the given character. Similar to ^ (carret)

# %%
match = re.search(r'\AHar',a)
print(match)
# Out:
# <re.Match object; span=(0, 3), match='Har'>

# %%
# Pot is present in the string but output is none because \A only find the pattern at the beginning of a string. SImilar to ^.

match = re.search(r'\APot',a) 
print(match)
# Out:
# None

# %%
match = re.findall(r'\APot','Pot Pot jxdxnPot bsjsjPot Potjjs') 
print(match)
# Out:
# ['Pot']

# %% [markdown]
# ### \Z: Matches the end of a string. Similar to $ (Dollar Sigh)

# %%
pattern = r'world!\Z'
text = 'Hello, world! world!'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['world!']

# %%
pattern = r'world!\Z'
text = 'world! hello'
matches = re.findall(pattern, text)
print(matches)
# Out:
# []

# %% [markdown]
# ### \d: Matches any decimal digit character and integer (equivalent to [0-9]).

# %%
match = re.search(r'\d','The number is 55 4.2a')
print(match)
# Out:
# <re.Match object; span=(14, 15), match='5'>

# %%
match = re.findall(r'\d','The number is 555 4.2a 7.5.6.5')
print(match)
# Out:
# ['5', '5', '5', '4', '2', '7', '5', '6', '5']

# %% [markdown]
# ### \d+: Matches one or more decimal digits. For example, the regex pattern "\d+" would match any string with one or more digits.

# %%
match = re.search(r'\d+','The number is 555 4.2a 555')
print(match)
# Out:
# <re.Match object; span=(14, 17), match='555'>

# %%
match = re.findall(r'\d+','The number is 555 4.2a 555')
print(match)
# Out:
# ['555', '4', '2', '555']

# %% [markdown]
# ### \D: Matches any non-digit character (equivalent to [^0-9]).

# %%
match = re.search(r'\D','The number is 55 4.2a')
print(match)
# Out:
# <re.Match object; span=(0, 1), match='T'>

# %%
match = re.findall(r'\D','The number is 55 4.2a')
print(match)
# Out:
# ['T', 'h', 'e', ' ', 'n', 'u', 'm', 'b', 'e', 'r', ' ', 'i', 's', ' ', ' ', '.', 'a']

# %% [markdown]
# ### \w: Matches any alphanumeric character (equivalent to [a-z,A-Z,0-9_]). Matching a word character:

# %%
match = re.search(r'\w','The number is 55 4.2a')
print(match)
# Out:
# <re.Match object; span=(0, 1), match='T'>

# %%
match = re.findall(r'\w','The number is 55 4.2a_$')
print(match)
# Out:
# ['T', 'h', 'e', 'n', 'u', 'm', 'b', 'e', 'r', 'i', 's', '5', '5', '4', '2', 'a', '_']

# %% [markdown]
# ### \W: Matches any non-alphanumeric character (equivalent to [^a-zA-Z0-9_]). Matching a non-word character.

# %%
match = re.search(r'\W','The number is 55 4.2a')
print(match)
# Out:
# <re.Match object; span=(3, 4), match=' '>

# %%
match = re.findall(r'\W','The number is 55 4.2a')
print(match)
# Out:
# [' ', ' ', ' ', ' ', '.']

# %% [markdown]
# ### \s: Matches any whitespace character (equivalent to [ \t\n\r\f\v]). Matching a whitespace character.

# %%
match = re.search(r'\s','The number is 4.2a')
print(match)
# Out:
# <re.Match object; span=(3, 4), match=' '>

# %%
match = re.findall(r'\s','The number is 4.2a')
print(match)
# Out:
# [' ', ' ', ' ']

# %% [markdown]
# ### \S: Matches any non-whitespace character (equivalent to [^ \t\n\r\f\v]). Matching a non-whitespace character.

# %%
match = re.search(r'\S','The number is 4.2a')
print(match)
# Out:
# <re.Match object; span=(0, 1), match='T'>

# %%
match = re.findall(r'\S','The number is 4.2a')
print(match)
# Out:
# ['T', 'h', 'e', 'n', 'u', 'm', 'b', 'e', 'r', 'i', 's', '4', '.', '2', 'a']

# %% [markdown]
# ### \b: Matches a word boundary (the beginning or end of a word).

# %%
# Jaha pe 'number' word ho output do

match = re.findall(r'\bnumber\b','The number is 4.2a')
print(match)
# Out:
# ['number']

# %%
# Special Sequences ko use krne ke liye regular expression se phle r likha zaroori hai warna kabhi kabhi spl. sequences kaam nahi krti hai.

match = re.findall('\bnumber\b','The number is 4.2a')
print(match)
# Out:
# []

# %%
# Double string lgane se fark nahi pdega r lagana important hai

match = re.findall("\bnumber\b",'The number is 4.2a')
print(match)
# Out:
# []

# %%
# Jaha pe 'number' ho uske baad kuch bhi hi ho output do

match = re.findall(r'number\b','The number is 4.2a')
print(match)
# Out:
# ['number']

# %%
# Phle kuch bhi ho uske baad 'number' ho, output do

match = re.findall(r'\bnumber','number is 4.2a')
print(match)
# Out:
# ['number']

# %%
# Pura word match hoga toh output dega warna nahi

match = re.findall(r'\bnumber','The numbe is 4.2a')
print(match)
# Out:
# []

# %% [markdown]
# ### \B: Matches a non-word boundary.

# %%
# Word ke andar 'cat' ho toh output do starting ya ending me ho toh output nahi dega.

pattern = r'\Bcat\B'
text = 'The acata in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['cat']

# %%
pattern = r'\Bcat\B'
text = 'The acat in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# []

# %%
pattern = r'\Bcat\B'
text = 'The cata in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# []

# %%
# Word ke andar pattern kitni bhi baar match ho output dega. 
# Starting ya ending me pattern match nahi krega. Only word ke andar pattern match krega.

pattern = r'\Bcat\B'
text = 'The acatcatcata in the hat.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['cat', 'cat', 'cat']

# %%
pattern = r'\tWorld'
text = 'Hello\World, Hello\nWorld'
matches = re.findall(pattern, text)
print(matches)
# Out:
# []

# %% [markdown]
# ### \t: Matches a tab character.

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello\tWorld')
# Out:
# Hello	World

# %%
pattern = r'\tWorld'

text = 'Hello	World, Hi	World'

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['\tWorld', '\tWorld']

# %%
pattern = r'World'

text = 'Hello	World, Hi	World'

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['World', 'World']

# %%
pattern = r'Hello\tWorld'

text = 'Hello\tWorld, Hello\nWorld'

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['Hello\tWorld']

# %%
# Starting 'hello' se ho then 1 ya zyda baar space ho fir 'world' ho

pattern = r'Hello\s+World'

text = 'Hello  World, Hello\tWorld'

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['Hello  World', 'Hello\tWorld']

# %% [markdown]
# ### \n: Matches a newline character.

# %%
print('Hello\nWorld')
# Out:
# Hello
# World

# %%
pattern = r'Hello\nWorld'

text = 'Hello\tWorld, Hello\nWorld'

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['Hello\nWorld']

# %% [markdown]
# # Functions in Regex
#
#
# * The re library in Python provides functions for working with regular expressions. These functions are use to perform various tasks.
#
#
# 1) re.search(pattern, string, flags=0): Searches the string for the first occurrence of the pattern, and returns a Match object if found. If not found, returns None.
#
#
# 2) re.compile(pattern, flags=0): Compiles a regular expression pattern into a regular expression object, which can be used for more efficient repeated matching.
#
#
# 3) re.match(pattern, string, flags=0): Matches the pattern at the beginning of the string, and returns a Match object if found. If not found, returns None.
#
#
# 4) re.findall(pattern, string, flags=0): Finds all non-overlapping occurrences of the pattern in the string, and returns them as a list of strings. The string is scanned left-to-right, and matches are returned in the order found.
#
#
# 5) re.sub(pattern, repl, string, count=0, flags=0): Replaces all occurrences of the pattern in the string with the replacement string repl, and returns the modified string.
#
#
# 6) re.split(pattern, string, maxsplit=0, flags=0): Splits the string at all occurrences of the pattern, and returns the parts as a list of strings.
#
#
# 7) re.finditer(pattern, string, flags=0): Returns an iterator that yields Match objects for each non-overlapping occurrence of the pattern in the string.
#
#
# 8) re.subn(): subn() is similar to sub() in all ways, except in its way of providing output. It returns a tuple with a count of the total of replacement and the new string rather than just the string.
#
#
# 9) re.escape(text): Returns string with all non-alphanumerics backslashed, this is useful if you want to match an arbitrary literal string that may have regular expression metacharacters in it.

# %% [markdown]
# ### 1) re.search(pattern, string, flags=0): Searches the string for the first occurrence of the pattern, and returns a Match object if found. If not found, returns None.

# %%
text = 'Hello, world world world!'
pattern = r'world'
match = re.search(pattern, text)
print(match)
# Out:
# <re.Match object; span=(7, 12), match='world'>

# %%
text = 'Hello, world world world!'
pattern = r'world'
match = re.search(pattern, text)
print(match.group())
# Out:
# world

# %%
text = 'Hello, world world world!'
pattern = r'hat'
match = re.search(pattern, text)
print(match)
# Out:
# None

# %% [markdown]
# ### 2) re.findall(pattern, string, flags=0): Finds all non-overlapping occurrences of the pattern in the string, and returns them as a list of strings. The string is scanned left-to-right, and matches are returned in the order found.

# %%
text = 'Hello, world world world!'
pattern = r'world'
match = re.findall(pattern, text)
print(match)
# Out:
# ['world', 'world', 'world']

# %%
text = 'Hello, world world world!'
pattern = r'hat'
match = re.findall(pattern, text)
print(match)
# Out:
# []

# %%
text = 'The quick brown fox jumps over the lazy dog.'
pattern = r'\b\w{4}\b'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['over', 'lazy']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'\d+'

match = re.findall(pattern, text)

print(match)
# Out:
# ['89', '90', '70']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'[A-Z]'

match = re.findall(pattern, text)

print(match)
# Out:
# ['J', 'L', 'D']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'[A-Z][a-z]'

match = re.findall(pattern, text)

print(match)
# Out:
# ['Jo', 'Li', 'Da']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'[A-Z][a-z]*'

match = re.findall(pattern, text)

print(match)
# Out:
# ['John', 'Lisa', 'David']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'[A-Z][a-z].*'

match = re.findall(pattern, text)

print(match)
# Out:
# ['John has scored 89 marks', 'Lisa has scored 90 marks', 'David has scored 70 marks']

# %% [markdown]
# ### 3) re.match(): Searches for a match at the beginning of the string and returns a match object if found. Returns None otherwise.

# %%
text = 'Hello, world world world!'
pattern = r'Hello'
match = re.match(pattern, text)
print(match)
# Out:
# <re.Match object; span=(0, 5), match='Hello'>

# %%
text = 'Hello, world world world!'
pattern = r'world'
match = re.match(pattern, text)
print(match)
# Out:
# None

# %% [markdown]
# ### 4) re.sub(pattern, repl, string, count=0, flags=0): Substitutes the matched string(s) with a replacement string.

# %%
text = 'Hello, world!'

pattern = r'world'

replacement = 'Python'

new_text = re.sub(pattern, replacement, text)

print(new_text)
# Out:
# Hello, Python!

# %%
match = re.sub(r'world','Python','Hello, world!')

print(match)
# Out:
# Hello, Python!

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'\s'

replacement = ''

match = re.sub(pattern, replacement, text)

print(match)
# Out:
# Johnhasscored89marksLisahasscored90marksDavidhasscored70marks

# %% [markdown]
# ### 5) subn() is similar to sub() in all ways, except in its way of providing output. It returns a tuple with a count of the total of replacement and the new string rather than just the string.

# %%
text = 'Hello, world!'

pattern = r'world'

replacement = 'Python'

new_text = re.subn(pattern, replacement, text)

print(new_text)
# Out:
# ('Hello, Python!', 1)

# %%
match = re.subn(r'world','Python','Hello, world world world!')

print(match)
# Out:
# ('Hello, Python Python Python!', 3)

# %% [markdown]
# ### 6) re.split(pattern, string, maxsplit=0, flags=0): Splits the text into a list of substrings at each match of the pattern.

# %%
text = 'The quick brown fox jumps quick over the lazy dog.'
pattern = r'quick'
words = re.split(pattern, text)
print(words)
# Out:
# ['The ', ' brown fox jumps ', ' over the lazy dog.']

# %%
text = 'The quick brown fox jumps quick over the lazy dog.'
pattern = r'quick'
words = re.split(pattern, text,maxsplit = 1)
print(words)
# Out:
# ['The ', ' brown fox jumps quick over the lazy dog.']

# %%
text = 'The quick brown fox jumps quick over the lazy dog.'
pattern = r'quick'
words = re.split(pattern, text,maxsplit = 4)
print(words)
# Out:
# ['The ', ' brown fox jumps ', ' over the lazy dog.']

# %% [markdown]
# ### 7) re.compile(pattern, flags=0):  Compiles a regular expression pattern into a regular expression object, which can be used for more efficient repeated matching.

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = re.compile(r'[a-d]')

match = re.findall(pattern, text)

print(match)
# Out:
# ['a', 'c', 'd', 'a', 'a', 'a', 'c', 'd', 'a', 'a', 'd', 'a', 'c', 'd', 'a']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = re.compile(r'[0-9]')

match = re.findall(pattern, text)

print(match)
# Out:
# ['8', '9', '9', '0', '7', '0']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = re.compile(r'[0-9]+')

match = re.findall(pattern, text)

print(match)
# Out:
# ['89', '90', '70']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = re.compile(r'[0-9]*')

match = re.findall(pattern, text)

print(match)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '89', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '90', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '70', '', '', '', '', '', '', '']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'[0-9]*'

match = re.findall(pattern, text)

print(match)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '89', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '90', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '70', '', '', '', '', '', '', '']

# %%
text = """John has scored 89 marks

Lisa has scored 90 marks

David has scored 70 marks"""

pattern = r'[a-d]'

match = re.findall(pattern, text)

print(match)
# Out:
# ['a', 'c', 'd', 'a', 'a', 'a', 'c', 'd', 'a', 'a', 'd', 'a', 'c', 'd', 'a']

# %%
match = re.compile(r'[a-d]','abcd')
print(match)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9972\2423400049.py in <module>
# ----> 1 match = re.compile(r'[a-d]','abcd')
#       2 print(match)
#
# ~\Anaconda3\lib\re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ~\Anaconda3\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~\Anaconda3\lib\sre_compile.py in compile(p, flags)
#     786     if isstring(p):
#     787         pattern = p
# --> 788         p = sre_parse.parse(p, flags)
#     789     else:
#     790         pattern = None
#
# ~\Anaconda3\lib\sre_parse.py in parse(str, flags, state)
#     953
#     954     try:
# --> 955         p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     956     except Verbose:
#     957         # the VERBOSE flag was switched on inside the pattern.  to be
#
# TypeError: unsupported operand type(s) for &: 'str' and 'int'

# %% [markdown]
# ### 8) re.escape(text): Returns string with all non-alphanumerics backslashed, this is useful if you want to match an arbitrary literal string that may have regular expression metacharacters in it.

# %%
text = """John has scored 89 marks.

Lisa has scored 90 marks.

David has scored 70 marks."""

match = re.escape(text)

print(match)
# Out:
# John\ has\ scored\ 89\ marks\.\
# \
# Lisa\ has\ scored\ 90\ marks\.\
# \
# David\ has\ scored\ 70\ marks\.

# %%
text = 'nhanck@.$*.'

match = re.escape(text)

print(match)
# Out:
# nhanck@\.\$\*\.

# %% [markdown]
# ### 9) re.finditer(pattern, string, flags=0): Returns an iterator yielding match objects for all non-overlapping matches of a regular expression pattern in the input string.

# %%
pattern = r'\d+'  

text = 'The quick brown fox jumps over the lazy dog 123 times.'

match = re.finditer(pattern, text)

print(match)
# Out:
# <callable_iterator object at 0x0000018802AF1130>

# %%
pattern = r'\d+'  # Matches one or more digits

text = 'The quick brown fox jumps over the lazy dog 123 times.'

# Use re.finditer() to find all matches
matches = re.finditer(pattern, text)

# Iterate over the matches and print their start and end positions
for match in matches:
    print('Match found:', match.group(), 'at position:', match.start(), '-', match.end())
# Out:
# Match found: 123 at position: 44 - 47

# %%
pattern = r'\d+|[a-b]'  # Matches one or more digits

text = 'The quick brown fox jumps over the lazy dog 123 times.'

# Use re.finditer() to find all matches
matches = re.finditer(pattern, text)

# Iterate over the matches and print their start and end positions
for match in matches:
    print('Match found:', match.group(), 'at position:', match.start(), '-', match.end())
# Out:
# Match found: b at position: 10 - 11
# Match found: a at position: 36 - 37
# Match found: 123 at position: 44 - 47

# %% [markdown]
# # Greedy VS Non-Greedy Approach / Regex

# %% [markdown]
# ## Greedy Regex
#
# In regular expressions, metacharacters like *, +, and { } are greedy by default, which means they try to match as many characters as possible.

# %% [markdown]
# ### Non-Greedy Regex
#
# Non-greedy, match as few characters as possible. You can make a greedy regex to non-greedy by appending a ? to it.

# %%
# Greedy approach

text = 'saaabbb jhhjbj aapp'

pattern = r'ab*' # 'a' 1 baar aaye or 'b' kitni bhi baar aaye or jaha pe 'b' ho usse phle 'a' zaroor aaye, aisa output dega

match = re.findall(pattern, text)

print(match)
# Out:
# ['a', 'a', 'abbb', 'a', 'a']

# %%
# Non-Greedy approach

text = 'saaabbb aapp b aabb ab'

pattern = r'ab?' # 'a' 1 baar aaye 'b' bhi 1 baar aaye or jaha pe 'b' aaye usse phle 'a' zaroor ho.
match = re.findall(pattern, text)

print(match)
# Out:
# ['a', 'a', 'ab', 'a', 'a', 'a', 'ab', 'ab']

# %%
# Greedy approach

text = 'aaabbbbbb'

pattern = r'ab{3,5}' # 'a' 1 baar aaye or 'b' 3-5 baar aaye

match = re.findall(pattern, text)

print(match)
# Out:
# ['abbbbb']

# %%
# Non-Greedy approach

text = 'aaabbbbbb'

pattern = r'ab{3,5}?' # 'a' 1 baar aaye or 'b' 3 baar aaye

match = re.findall(pattern, text)

print(match)
# Out:
# ['abbb']

# %%
# Greedy approach

text = 'A <div>foo</div> bar <div>baz</div> qux'

pattern = r'<div>.*</div>' # jaha bhi '<div>' ho uske baad kuch bhi ho kitni bhi baar ho output do

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['<div>foo</div> bar <div>baz</div>']

# %%
# Non-greedy approach

text = 'A <div>foo</div> bar <div>baz</div> qux'

pattern = r'<div>.*?</div>' # jaha bhi '<div>' ho uske baad kuch bhi ho kitni bhi baar, kya aisa pattern hai string me? or uske 
                            # baad fir '<div>' ho.
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['<div>foo</div>', '<div>baz</div>']

# %%
# Greedy approach

text = "<HTML><TITLE>My Page</TITLE></HTML>"

pattern = r'<.*>' # starting '<' ho ending '>' ho beech me kuch ho kitni bhi baar ho

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['<HTML><TITLE>My Page</TITLE></HTML>']

# %%
# Non-Greedy approach

text = "<HTML><TITLE>My Page</TITLE></HTML>"

pattern = r'<.*?>' # starting '<' ho beech me kuch bhi ho kitni hi baar ho, kya aisa pattern hai apne pass or last me '>' ho
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['<HTML>', '<TITLE>', '</TITLE>', '</HTML>']

# %%
# Thing to be note:- be sure that where to use ? in between pattern otherwise it will not give the result you want

text = "<HTML><TITLE>My Page</TITLE></HTML>"

pattern = r'<.*>?' # starting '<' ho beech me kuch bhi ho kitni hi baar ho, kya aisa pattern hai apne pass or last me '>' ho
matches = re.findall(pattern, text)

print(matches)
# Out:
# ['<HTML><TITLE>My Page</TITLE></HTML>']

# %% [markdown]
# # Match Object
#
#
# * A match object contains all the information about the search and the result and if there is no match found then, None will be returned.
#
#
# * i.e: <re.Match object; span=(0, 6), match='sameer'>

# %%
text = "John has scored 98 marks."

pattern = r'\d+'

match = re.search(pattern, text)

# It will give the output that whether the pattern is found or not. 
# If found, then it will give their index location, where the pattern is found in the string.
# Also output the the result, what it found by given regex pattern.

print(match)
# Out:
# <re.Match object; span=(16, 18), match='98'>

# %%
# '.re' use to search the which regex has been used to search the pattern

print(match.re)
# Out:
# re.compile('\\d+')

# %%
# '.string' is use to search the string or text of the given pattern.

print(match.string)
# Out:
# John has scored 98 marks.

# %%
# '.start()' is use to find the starting location where the pattern is found

print(match.start())
# Out:
# 16

# %%
# '.end()' is use to find the ending location where the pattern is found

print(match.end())
# Out:
# 18

# %%
# '.span' is used to search the index location where the pattern is found.

print(match.span())
# Out:
# (16, 18)

# %%
# '.group()' is used to search that what our regex is found by given pattern in the string.

print(match.group())
# Out:
# 98

# %% [markdown]
# # Phone Number and Email Verification and Web Scrapping using Regex.

# %%
# How to verify Phone Numbers.

phn_num = ['552-782-1495', '547-325-7456', '785-a65-8525', '513-5411-526']

pattern = r'^\d{3}-\d{3}-\d{4}$'

for phone_number in phn_num:
    match = re.match(pattern, phone_number)
    if match:
        print(f"{phone_number} :- is a valid phone number.\n")
    else:
        print(f"{phone_number} :- is not a valid phone number.\n")
# Out:
# 552-782-1495 :- is a valid phone number.
#
# 547-325-7456 :- is a valid phone number.
#
# 785-a65-8525 :- is not a valid phone number.
#
# 513-5411-526 :- is not a valid phone number.

# %%
# How to verify email address

emails = ['random.guy123@gmail.com', 'mr_x_in_bombay@gov.in', '1@ued.org','@gmail.com','abc!@yahoo.in', 'sam_12@gov.us',
          'neeraj@']

pattern = r'^.*@.*\.(com|in)$' # This regex is right but usefull but not everytime.


for email in emails:
    match = re.match(pattern, email)
    if match:
        print(f"{email} :- is a valid email.\n")
    else:
        print(f"{email} :- is not a valid is a valid email.\n")
# Out:
# random.guy123@gmail.com :- is a valid email.
#
# mr_x_in_bombay@gov.in :- is a valid email.
#
# 1@ued.org :- is not a valid is a valid email.
#
# @gmail.com :- is a valid email.
#
# abc!@yahoo.in :- is a valid email.
#
# sam_12@gov.us :- is not a valid is a valid email.
#
# neeraj@ :- is not a valid is a valid email.

# %%
# Emails that should match: random.guy123@gmail.com, mr_x_in_bombay@gov.in


emails = ['random.guy123@gmail.com', 'mr_x_in_bombay@gov.in', '1@ued.org','@gmail.com','abc!@yahoo.in', 'sam_12@gov.us',
          'neeraj@']

pattern = r'^\S{1,}@.*\.(com|in)$'

for email in emails:
    match = re.match(pattern, email)
    if match:
        print(f"{email} :- is a valid email.\n")
    else:
        print(f"{email} :- is not a valid is a valid email.\n")
# Out:
# random.guy123@gmail.com :- is a valid email.
#
# mr_x_in_bombay@gov.in :- is a valid email.
#
# 1@ued.org :- is not a valid is a valid email.
#
# @gmail.com :- is not a valid is a valid email.
#
# abc!@yahoo.in :- is a valid email.
#
# sam_12@gov.us :- is not a valid is a valid email.
#
# neeraj@ :- is not a valid is a valid email.

# %%
# Emails that should match: random.guy123@gmail.com, mr_x_in_bombay@gov.in


emails = ['random.guy123@gmail.com', 'mr_x_in_bombay@gov.in', '1@ued.org','@gmail.com','abc!@yahoo.in', 'sam_12@gov.us',
          'neeraj@']

pattern = r'[\w.%_].*@.*\.(com|in)$'

for email in emails:
    match = re.match(pattern, email)
    if match:
        print(f"{email} :- is a valid email.\n")
    else:
        print(f"{email} :- is not a valid is a valid email.\n")
# Out:
# random.guy123@gmail.com :- is a valid email.
#
# mr_x_in_bombay@gov.in :- is a valid email.
#
# 1@ued.org :- is not a valid is a valid email.
#
# @gmail.com :- is not a valid is a valid email.
#
# abc!@yahoo.in :- is a valid email.
#
# sam_12@gov.us :- is not a valid is a valid email.
#
# neeraj@ :- is not a valid is a valid email.

# %% [markdown]
# ### Web Scrapping using Regex

# %%
import requests

# %%
url = 'https://www.fakepersongenerator.com/random-address.html'
response = requests.get(url)
html_text = response.text

# Extract all phone numbers from the HTML
phone_numbers = re.findall(r'\d{3}-\d{3}-\d{4}', html_text)

# Print the results
for i in phone_numbers:
    print(i)
# Out:
# 818-509-6772
# 818-463-9850

# %%
url = 'https://usaddressgenerator.com/'
response = requests.get(url)
html_text = response.text

# Extract all phone numbers from the HTML
phone_numbers = re.findall(r'\(\d{3}\) \d{3}-\d{4}', html_text)

# Print the results
for i in phone_numbers:
    print(i)
# Out:
# (206) 463-5153
# (207) 774-6884
# (207) 774-6884
# (208) 468-9709
# (208) 489-3101
# (208) 726-8729
# (208) 726-8729
# (208) 734-9611
# (208) 734-9611
# (951) 487-8914
# (805) 643-9424
# (805) 529-1832
# (530) 275-4140
# (530) 257-0914
# (415) 467-3419
# (760) 771-1781
# (909) 267-9440
# (714) 961-6811
# (714) 826-8310
# (951) 699-2321
# (760) 637-2644
# (714) 484-6711
# (916) 415-0893
# (760) 636-5648
# (619) 283-2035
# (805) 529-0264
# (760) 200-3316
# (661) 878-8389
# (760) 379-2780
# (805) 569-2622
# (510) 888-9108
# (805) 938-5595
# (916) 339-2704
# (310) 370-3228
# (805) 733-0295
# (303) 494-5435
# (307) 576-2224
# (307) 734-5242
# (317) 440-5897
# (317) 440-5897
# (406) 844-3525
# (410) 727-8665
# (435) 257-2404
# (435) 673-4805
# (208) 752-4051
# (208) 746-5727
# (208) 624-7695
# (208) 347-2820
# (208) 459-6587
# (208) 743-8191
# (208) 836-5708
# (208) 362-0456
# (208) 773-4079
# (303) 494-5435
# (307) 576-2224
# (307) 734-5242
# (317) 440-5897
# (317) 440-5897
# (406) 844-3525
# (410) 727-8665
# (435) 257-2404
# (435) 673-4805
# (805) 497-6611
# (907) 267-1712
# (907) 267-1712
# (916) 536-1262
# (951) 679-6099
# (972) 272-1941
# (989) 773-2654
# (208) 687-0157
# (731) 286-2466
# (760) 596-3310
# (762) 338-5022
# (762) 435-7065
# (762) 435-7110
# (762) 435-7127
# (762) 435-7131
# (762) 524-7002
# (762) 524-7002
# (770) 271-8757
# (770) 973-7206
# (770) 761-0904
# (470) 326-5558
# (706) 245-7740
# (706) 364-0791
# (678) 475-6536
# (229) 931-0536
# (770) 992-8799
# (254) 867-8088
# (281) 236-8332
# (281) 236-8332
# (304) 422-6126
# (314) 385-8900
# (318) 323-2536
# (318) 323-2536
# (334) 448-5589
# (334) 529-4641
# (864) 654-7898
# (864) 685-5278
# (864) 760-0500
# (865) 573-5427
# (865) 573-5427
# (866) 228-2038
# (870) 777-9170
# (902) 897-2814
# (603) 239-6809
# (603) 673-2228
# (603) 601-2921
# (603) 542-2791
# (603) 528-2645
# (603) 539-2250
# (603) 673-4329
# (603) 323-8714
# (603) 624-1433
# (603) 497-2558
# (603) 522-8380
# (603) 456-2342
# (603) 642-5749
# (603) 542-6914
# (603) 249-5794
# (603) 595-3515
# (603) 447-6512
# (603) 242-6228
# (310) 392-0212
# (405) 722-0901
# (405) 790-0629
# (407) 343-5443
# (508) 587-7586
# (508) 999-8009
# (603) 204-5765
# (603) 206-5445
# (603) 206-5515
# (603) 224-6551
# (603) 367-8068
# (603) 437-7806
# (603) 669-9215
# (603) 740-0019
# (603) 912-5245
# (603) 632-9256
# (603) 432-7720
# (619) 421-0855
# (702) 212-0746
# (702) 212-0746
# (702) 220-3384
# (702) 220-3384
# (702) 221-6262
# (702) 228-8679
# (702) 228-8679
# (702) 233-2984
# (775) 423-4881
# (775) 434-7933
# (702) 346-7518
# (775) 826-6034
# (775) 831-7877
# (775) 423-2077
# (760) 385-5218
# (775) 423-6604
# (775) 289-2811
# (775) 324-3429
# (702) 649-3385
# (775) 289-6874
# (702) 369-7177
# (775) 424-2145
# (775) 727-7502
# (775) 241-2156
# (775) 423-3000
# (775) 246-5576
# (402) 291-8097
# (406) 883-4365
# (410) 574-8936
# (410) 574-8936
# (530) 577-2760
# (530) 878-3928
# (541) 416-1963
# (619) 421-0855
# (512) 847-7978
# (469) 464-3127
# (281) 479-5898
# (254) 793-3321
# (254) 793-2450
# (903) 884-2384
# (806) 274-4138
# (817) 677-3655
# (817) 596-9202
# (903) 965-5220
# (817) 964-3467
# (956) 725-1731
# (210) 310-2468
# (210) 257-8074
# (409) 579-4251
# (830) 643-1505
# (830) 651-1968
# (806) 892-3167
# (361) 884-0784
# (325) 651-1361
# (903) 870-5086
# (817) 562-3272
# (281) 470-2516
# (432) 264-7804
# (254) 647-5453
# (903) 560-9830
# (253) 262-3400
# (409) 625-4584
# (512) 559-0859
# (817) 430-1252
# (512) 601-2054
# (830) 896-3009
# (832) 717-0176
# (281) 462-7671
# (956) 550-0648
# (850) 224-5629
# (904) 645-3523
# (910) 937-0978
# (970) 835-8955
# (808) 242-2766
# (808) 961-3783
# (808) 669-9655
# (808) 261-1189
# (808) 941-0018
# (760) 324-5613
# (808) 200-2950
# (808) 200-3820
# (808) 200-4423
# (808) 200-7885
# (808) 206-7519
# (808) 206-8202
# (808) 206-8202
# (808) 206-9544
# (808) 200-2950
# (808) 200-3820
# (808) 200-4423
# (808) 200-7885
# (808) 206-7519
# (808) 206-8202
# (808) 206-8202
# (808) 206-9544
# (808) 206-9617
# (760) 324-5613
# (808) 200-2950
# (808) 200-3820
# (808) 200-4423
# (808) 200-7885
# (808) 206-7519
# (808) 206-8202
# (808) 206-8202
# (515) 966-0029
# (319) 373-7632
# (563) 588-0010
# (515) 966-2869
# (712) 947-4486
# (563) 556-2750
# (641) 584-2793
# (563) 432-7764
# (319) 550-1815
# (712) 246-5149
# (319) 208-9763
# (515) 523-2735
# (563) 219-8151
# (515) 733-4073
# (515) 733-1222
# (515) 984-6510
# (712) 385-8288
# (712) 255-1860
# (515) 597-2881
# (712) 468-2080
# (641) 464-4433
# (515) 389-3455
# (712) 335-4238
# (563) 241-1228
# (515) 733-2540
# (319) 887-9114
# (712) 843-2251
# (706) 462-2762
# (708) 485-1403
# (712) 200-1964
# (712) 200-2397
# (712) 200-2499
# (712) 200-3955
# (712) 213-0096
# (712) 213-0161
# (970) 476-4777
# (970) 563-9438
# (970) 522-6755
# (970) 476-4777
# (303) 822-9720
# (303) 659-5651
# (303) 979-0848
# (970) 667-6557
# (970) 669-4767
# (920) 496-0693
# (928) 764-3418
# (931) 273-7962
# (970) 203-0353
# (970) 203-0353
# (970) 203-0624
# (970) 203-0624
# (970) 203-0747
# (970) 203-0747
# (970) 332-4618
# (303) 440-8378
# (970) 526-6138
# (303) 278-9981
# (303) 682-0723
# (719) 868-3068
# (303) 693-1803
# (970) 736-2867
# (970) 593-0239
# (970) 230-9457
# (719) 687-0776
# (303) 655-3793
# (303) 955-8286
# (303) 537-7716
# (719) 686-1449
# (303) 371-8757
# (719) 658-2839
# (931) 387-2359
# (931) 721-4674
# (423) 256-9459
# (423) 323-7488
# (931) 285-2289
# (901) 850-1782
# (931) 722-7665
# (901) 383-9804
# (615) 563-6873
# (931) 387-2359
# (931) 721-4674
# (423) 256-9459
# (423) 323-7488
# (931) 285-2289
# (901) 850-1782
# (931) 722-7665
# (901) 383-9804
# (615) 563-6873
# (615) 279-5308
# (423) 282-6511
# (865) 637-9133
# (423) 626-3817
# (731) 855-4938
# (423) 245-1119
# (615) 361-0993
# (931) 268-5101
# (731) 538-3496
# (405) 728-3807
# (407) 339-4991
# (423) 201-9352
# (423) 201-9390
# (423) 201-9449
# (423) 201-9449
# (423) 202-3256
# (423) 202-3874
# (802) 635-7580
# (802) 524-0898
# (802) 626-4195
# (802) 868-0017
# (802) 747-1440
# (802) 879-4214
# (802) 485-8005
# (802) 468-0049
# (802) 247-8511
# (602) 938-2192
# (603) 298-5491
# (603) 336-6092
# (603) 352-1600
# (603) 627-0626
# (603) 835-6156
# (603) 835-6156
# (651) 784-8000
# (727) 577-3053
# (401) 789-3995
# (503) 231-2744
# (602) 938-2192
# (603) 298-5491
# (603) 336-6092
# (603) 352-1600
# (603) 627-0626
# (603) 835-6156
# (603) 835-6156
# (651) 784-8000
# (727) 577-3053
# (765) 963-2065
# (770) 345-7446
# (800) 426-7820
# (800) 541-7795
# (800) 843-2600
# (802) 222-4067
# (307) 362-5326
# (307) 334-3285
# (307) 674-7200
# (307) 587-4828
# (307) 279-3056
# (307) 782-3163
# (307) 789-4029
# (307) 742-9097
# (702) 437-2742
# (734) 782-0231
# (912) 285-1708
# (970) 353-6642
# (970) 756-5088
# (307) 367-4571
# (307) 682-9248
# (307) 672-6750
# (307) 686-0192
# (307) 778-9152
# (307) 673-0072
# (307) 548-2837
# (307) 234-3604
# (307) 367-3394
# (307) 672-7453
# (307) 789-8748
# (307) 235-1550
# (307) 789-3182
# (734) 782-0231
# (912) 285-1708
# (970) 353-6642
# (970) 756-5088
# (307) 367-4571
# (307) 682-9248
# (307) 672-6750
# (307) 686-0192
# (318) 757-8383
# (334) 480-2263
# (334) 699-2143
# (601) 202-7059
# (601) 206-1342
# (601) 206-8891
# (601) 206-9030
# (601) 208-0235
# (601) 222-0099
# (662) 205-4169
# (662) 205-4686
# (662) 205-7122
# (662) 219-0169
# (662) 219-0187
# (662) 219-0522
# (662) 219-0550
# (662) 219-0555
# (931) 906-1828
# (985) 735-5101
# (662) 838-3026
# (662) 233-2159
# (601) 267-9831
# (601) 587-4625
# (662) 252-5465
# (601) 483-6232
# (662) 337-4382
# (601) 776-1091
# (601) 384-1670
# (662) 665-9998
# (228) 474-8287
# (662) 890-4148
# (601) 737-2541
# (601) 346-8325
# (662) 534-2428
# (307) 674-4809
# (308) 284-0942
# (442) 635-1202
# (442) 635-1202
# (605) 213-0071
# (605) 213-0483
# (605) 223-2246
# (605) 223-2325
# (605) 223-2425
# (605) 213-0071
# (605) 213-0483
# (605) 223-2246
# (605) 223-2325
# (605) 223-2425
# (605) 223-2460
# (605) 223-2672
# (605) 223-2802
# (605) 223-2823
# (925) 949-7807
# (605) 642-1783
# (605) 333-0562
# (605) 886-1050
# (605) 853-3428
# (605) 853-3428
# (605) 397-4494
# (605) 882-0964
# (605) 432-7858
# (925) 949-7807
# (605) 642-1783
# (605) 333-0562
# (605) 886-1050
# (605) 853-3428
# (605) 853-3428
# (605) 397-4494
# (605) 882-0964
# (817) 279-6641
# (877) 888-8401
# (877) 888-8401
# (928) 342-5699
# (954) 566-9843
# (970) 223-4887
# (360) 651-8196
# (509) 684-6001
# (360) 387-7147
# (650) 697-3622
# (651) 365-0822
# (651) 365-0822
# (703) 690-2795
# (704) 788-9372
# (720) 565-0900
# (760) 416-3766
# (760) 416-3766
# (760) 751-2712
# (610) 237-8402
# (610) 237-8402
# (615) 989-1388
# (650) 697-3622
# (651) 365-0822
# (651) 365-0822
# (703) 690-2795
# (704) 788-9372
# (720) 565-0900
# (509) 886-2098
# (509) 886-2722
# (509) 886-4248
# (509) 886-4608
# (509) 886-8008
# (509) 886-8660
# (509) 886-8783
# (509) 888-0759
# (585) 457-9945
# (607) 564-7178
# (607) 785-5487
# (718) 672-2967
# (718) 951-6361
# (518) 357-0649
# (718) 956-0189
# (518) 729-2530
# (518) 835-2096
# (512) 671-8674
# (515) 228-0356
# (516) 205-2961
# (516) 208-3491
# (516) 208-3991
# (516) 208-5004
# (516) 208-5324
# (516) 208-6386
# (516) 208-6733
# (716) 216-4442
# (518) 238-3758
# (716) 782-4967
# (315) 333-1107
# (585) 384-5157
# (845) 439-4036
# (585) 346-7103
# (518) 877-0011
# (716) 668-4657
# (562) 201-1232
# (570) 253-2853
# (570) 421-4593
# (570) 461-3426
# (570) 588-6855
# (570) 828-9612
# (585) 201-7021
# (585) 201-7422
# (620) 626-5823
# (913) 334-0430
# (785) 825-5123
# (316) 321-3710
# (913) 756-2508
# (785) 392-2913
# (913) 651-2909
# (620) 834-2203
# (913) 233-0855
# (512) 232-6197
# (573) 765-9928
# (620) 204-6091
# (620) 213-8503
# (620) 218-3146
# (620) 221-0073
# (620) 221-0173
# (620) 221-0496
# (620) 221-0906
# (785) 667-2783
# (785) 820-9291
# (913) 586-5079
# (620) 457-8789
# (913) 788-2046
# (620) 674-3475
# (913) 254-1126
# (785) 836-2393
# (785) 582-4471
# (620) 204-6091
# (620) 213-8503
# (620) 218-3146
# (620) 221-0073
# (620) 221-0173
# (620) 221-0496
# (620) 221-0906
# (620) 221-0990
# (260) 350-1051
# (314) 830-3823
# (320) 202-0892
# (320) 202-1841
# (320) 202-2976
# (320) 202-7709
# (320) 202-9705
# (320) 203-1266
# (605) 338-1182
# (605) 352-3929
# (605) 528-3819
# (605) 694-2705
# (605) 997-2346
# (612) 246-3930
# (612) 302-9683
# (612) 331-9551
# (612) 333-6457
# (952) 890-1447
# (218) 847-6605
# (952) 401-8074
# (952) 933-3637
# (218) 463-2284
# (320) 676-1846
# (763) 425-3580
# (218) 463-0025
# (507) 375-7208
# (904) 543-0481
# (904) 620-8457
# (910) 989-2200
# (937) 836-0010
# (952) 203-1057
# (952) 217-4975
# (952) 217-5556
# (602) 216-9302
# (602) 216-9302
# (602) 218-6480
# (602) 218-6480
# (602) 237-0064
# (602) 237-2553
# (602) 237-3450
# (602) 237-3558
# (602) 237-3734
# (928) 202-3805
# (928) 202-3810
# (928) 203-0386
# (928) 203-0922
# (928) 203-9143
# (928) 203-9360
# (928) 203-9420
# (928) 204-1503
# (928) 204-5501
# (281) 485-3130
# (360) 403-9345
# (360) 595-0268
# (406) 883-5248
# (435) 676-8335
# (440) 934-4619
# (480) 207-1742
# (480) 207-1742
# (480) 214-3194
# (505) 777-2408
# (509) 773-3683
# (520) 203-8468
# (520) 203-8468
# (520) 207-0289
# (520) 207-0289
# (520) 207-2811
# (520) 207-3885
# (401) 728-8123
# (401) 635-2646
# (401) 944-1416
# (401) 789-6060
# (401) 885-7311
# (401) 781-3132
# (401) 398-2395
# (401) 284-0450
# (401) 826-3539
# (401) 943-0027
# (401) 828-1644
# (401) 274-2967
# (401) 769-0908
# (401) 822-1019
# (401) 825-7746
# (401) 826-7357
# (401) 475-4068
# (401) 351-1301
# (781) 224-1767
# (781) 255-4870
# (828) 835-9475
# (860) 405-0215
# (860) 405-8015
# (860) 442-8615
# (860) 848-4445
# (888) 208-7517
# (401) 823-9532
# (401) 231-5829
# (401) 475-0767
# (401) 349-3823
# (401) 295-7580
# (401) 295-8557
# (401) 821-1268
# (401) 270-5947
# (401) 635-8814
# (619) 338-8333
# (702) 869-8881
# (720) 497-2436
# (760) 530-5660
# (775) 777-2119
# (800) 596-2953
# (801) 208-3949
# (801) 208-3981
# (801) 209-5559
# (801) 298-1471
# (435) 635-7052
# (801) 292-4125
# (801) 254-6805
# (801) 766-8806
# (801) 254-4778
# (801) 487-9308
# (801) 692-1413
# (801) 250-0305
# (801) 561-0661
# (801) 491-4908
# (435) 644-3117
# (801) 295-0266
# (435) 678-7873
# (435) 789-6806
# (435) 644-5019
# (801) 489-8416
# (435) 831-4703
# (435) 574-0444
# (435) 657-2035
# (435) 586-8117
# (801) 768-8182
# (435) 896-1908
# (801) 667-3823
# (435) 336-3332
# (612) 816-1541
# (612) 897-5612
# (617) 298-3420
# (617) 426-9052
# (631) 283-7280
# (631) 283-7280
# (702) 990-3033
# (702) 990-3033
# (706) 561-1354
# (612) 816-1541
# (612) 897-5612
# (617) 298-3420
# (617) 426-9052
# (631) 283-7280
# (631) 283-7280
# (702) 990-3033
# (702) 990-3033
# (706) 561-1354
# (207) 244-3030
# (212) 809-3542
# (212) 809-3542
# (215) 528-5686
# (230) 438-8821
# (252) 459-3034
# (252) 744-5820
# (260) 357-6867
# (301) 924-6556
# (715) 458-2224
# (724) 656-9350
# (770) 422-2959
# (772) 336-3563
# (780) 472-5268
# (781) 893-7921
# (781) 893-7921
# (812) 492-1210
# (843) 774-3789
# (863) 858-5456
# (865) 660-9138
# (302) 422-3892
# (302) 832-2749
# (302) 322-1183
# (302) 836-9707
# (302) 539-0502
# (302) 328-5603
# (843) 774-3789
# (863) 858-5456
# (865) 660-9138
# (302) 422-3892
# (302) 832-2749
# (302) 322-1183
# (302) 836-9707
# (302) 539-0502
# (302) 328-5603
# (302) 422-3892
# (302) 832-2749
# (302) 322-1183
# (302) 836-9707
# (302) 539-0502
# (302) 328-5603
# (302) 697-6231
# (302) 792-0327
# (302) 376-0314
# (843) 774-3789
# (863) 858-5456
# (865) 660-9138
# (302) 422-3892
# (302) 832-2749
# (302) 322-1183
# (302) 836-9707
# (302) 539-0502
# (479) 203-0279
# (479) 203-3139
# (479) 203-7047
# (479) 203-7092
# (479) 203-9984
# (479) 219-3035
# (479) 219-3789
# (479) 224-0089
# (479) 224-6085
# (501) 327-0316
# (479) 451-8010
# (501) 589-3707
# (479) 443-9066
# (870) 343-8703
# (870) 693-5950
# (501) 463-9349
# (870) 793-6694
# (501) 336-0691
# (614) 850-8773
# (662) 438-7269
# (662) 578-2951
# (704) 528-4556
# (719) 275-2209
# (719) 544-7454
# (775) 348-4727
# (813) 737-5381
# (816) 523-6504
# (501) 796-2411
# (870) 234-3113
# (870) 836-3956
# (479) 855-9714
# (870) 653-5102
# (479) 268-6261
# (479) 641-5557
# (479) 587-1464
# (845) 469-4639
# (845) 876-4165
# (916) 988-8915
# (207) 293-4007
# (207) 882-4757
# (207) 834-7142
# (207) 495-3762
# (207) 454-7773
# (207) 866-4680
# (617) 253-5018
# (651) 222-3269
# (707) 838-8621
# (740) 592-5638
# (763) 675-2975
# (800) 300-7708
# (845) 469-4639
# (845) 876-4165
# (916) 988-8915
# (508) 540-4826
# (512) 658-6740
# (530) 273-7751
# (561) 367-1626
# (561) 747-4448
# (601) 681-9207
# (603) 244-2215
# (603) 335-8041
# (603) 343-2777
# (603) 244-2215
# (603) 335-8041
# (603) 343-2777
# (603) 437-7003
# (603) 664-2441
# (603) 679-1579
# (603) 841-7230
# (603) 859-5316
# (253) 862-4970
# (303) 674-2205
# (417) 926-4891
# (480) 284-7704
# (601) 703-9217
# (601) 703-9217
# (630) 993-2040
# (630) 993-2040
# (701) 205-0192
# (701) 428-0137
# (701) 652-1050
# (701) 754-2855
# (701) 428-3066
# (701) 744-5331
# (701) 532-0658
# (701) 281-1268
# (701) 532-0658
# (701) 754-2581
# (701) 675-2395
# (701) 772-3637
# (701) 678-6877
# (701) 772-3182
# (701) 462-8211
# (701) 246-3261
# (701) 678-2546
# (701) 228-2816
# (701) 352-2767
# (701) 352-1934
# (701) 224-1266
# (701) 742-3243
# (701) 742-2353
# (701) 852-7323
# (701) 437-2143
# (701) 742-3561
# (701) 742-2751
# (713) 454-1287
# (713) 686-6929
# (717) 938-9991
# (763) 427-2706
# (830) 741-8271
# (850) 235-6169
# (850) 944-4290
# (866) 306-3270
# (870) 696-2985
# (318) 202-3259
# (318) 202-3767
# (318) 202-5359
# (318) 202-5425
# (318) 202-5538
# (318) 202-5555
# (318) 202-5763
# (318) 209-4065
# (985) 201-7688
# (985) 201-8575
# (985) 201-7688
# (985) 201-8575
# (985) 206-5065
# (985) 206-5154
# (985) 206-9064
# (985) 206-9627
# (985) 218-9078
# (985) 218-9137
# (985) 218-9192
# (985) 206-5065
# (985) 206-5154
# (985) 206-9064
# (985) 206-9627
# (985) 218-9078
# (985) 218-9137
# (651) 251-1220
# (651) 251-1220
# (727) 733-4741
# (740) 367-0680
# (740) 456-5524
# (740) 533-3977
# (740) 574-0223
# (740) 867-6121
# (740) 867-8537
# (614) 877-3868
# (615) 731-8285
# (615) 824-2788
# (616) 662-7684
# (651) 251-1220
# (651) 251-1220
# (727) 733-4741
# (740) 367-0680
# (740) 456-5524
# (270) 206-4043
# (270) 206-4239
# (270) 206-4247
# (270) 206-7097
# (270) 206-9111
# (270) 206-9159
# (270) 208-1002
# (270) 208-1013
# (270) 208-1028
# (606) 215-3125
# (606) 215-3137
# (606) 215-3315
# (606) 215-3358
# (606) 215-3526
# (606) 218-6186
# (606) 220-0153
# (606) 235-2000
# (973) 283-1090
# (732) 873-9070
# (201) 843-6651
# (201) 342-2031
# (732) 442-6363
# (973) 485-5664
# (973) 916-2695
# (732) 382-4078
# (973) 442-1945
# (803) 648-2100
# (804) 727-1402
# (812) 849-6434
# (814) 887-2737
# (816) 220-1001
# (816) 225-0421
# (817) 215-9821
# (817) 366-0245
# (828) 743-2976
# (908) 222-1091
# (856) 307-9447
# (973) 478-2708
# (609) 499-0800
# (732) 469-4429
# (732) 657-1524
# (908) 653-1134
# (201) 768-2538
# (732) 446-2676
# (732) 745-1991
# (973) 226-2775
# (732) 548-1332
# (201) 444-6880
# (201) 791-2672
# (732) 833-9396
# (609) 573-5206
# (732) 868-0536
# (601) 824-3484
# (605) 624-7222
# (605) 655-5936
# (620) 455-3805
# (706) 796-0325
# (712) 256-3967
# (712) 274-7364
# (712) 322-0033
# (712) 352-1025
# (913) 592-2339
# (402) 379-4786
# (402) 924-3012
# (402) 685-5832
# (308) 986-2256
# (402) 387-2308
# (402) 235-3518
# (402) 336-3648
# (402) 388-4564
# (303) 576-6601
# (308) 220-0003
# (308) 221-2044
# (308) 221-2098
# (308) 221-2328
# (308) 221-2544
# (308) 221-5069
# (308) 221-5211
# (308) 221-5229
# (402) 614-5974
# (308) 236-9817
# (402) 747-8031
# (308) 743-2128
# (402) 727-4809
# (402) 645-3648
# (308) 534-3150
# (334) 209-0089
# (334) 209-0196
# (334) 209-0324
# (334) 209-0660
# (334) 209-1559
# (334) 209-2770
# (334) 213-1193
# (334) 213-4016
# (334) 213-4016
# (601) 425-3305
# (601) 735-5478
# (615) 860-1448
# (618) 632-3836
# (618) 632-3836
# (662) 231-8231
# (662) 327-5975
# (662) 568-3417
# (662) 676-8542
# (850) 267-2325
# (850) 470-9878
# (850) 475-5030
# (863) 965-0875
# (865) 498-0309
# (870) 594-4896
# (920) 592-6065
# (931) 686-8512
# (931) 920-0472
# (205) 371-4642
# (205) 681-8983
# (205) 681-7969
# (205) 681-1380
# (334) 563-9557
# (334) 393-0483
# (205) 384-3857
# (256) 892-4379
# (812) 275-5384
# (765) 724-2621
# (260) 837-7693
# (260) 599-0992
# (812) 367-2065
# (812) 883-4835
# (812) 858-9624
# (765) 282-3629
# (219) 947-4827
# (219) 210-3487
# (219) 210-3487
# (219) 210-3785
# (219) 210-3785
# (219) 213-2687
# (219) 213-2687
# (219) 221-6304
# (219) 221-6304
# (219) 221-6894
# (574) 204-2280
# (574) 204-2862
# (574) 204-2919
# (574) 207-5027
# (574) 207-5056
# (574) 207-5101
# (574) 207-5150
# (574) 217-7025
# (574) 217-7518
# (904) 725-9769
# (931) 858-6881
# (937) 746-0886
# (937) 878-1179
# (952) 914-9635
# (812) 490-7806
# (765) 345-7882
# (317) 830-8360
# (907) 283-0548
# (907) 335-3331
# (907) 283-2799
# (907) 247-8287
# (907) 283-6173
# (907) 753-0155
# (907) 586-8164
# (907) 225-4144
# (907) 262-2578
# (907) 895-5010
# (907) 694-7675
# (907) 220-9019
# (907) 822-3605
# (907) 225-9273
# (907) 262-6261
# (907) 826-3317
# (907) 523-5680
# (907) 822-3177
# (907) 631-3885
# (907) 486-2612
# (907) 247-9199
# (907) 789-7623
# (907) 225-4540
# (907) 457-2631
# (907) 745-0175
# (907) 696-3131
# (907) 357-4333
# (240) 375-1288
# (307) 682-8835
# (405) 608-0551
# (901) 324-3127
# (907) 220-1980
# (907) 220-9964
# (907) 222-1151
# (907) 222-1151
# (772) 460-9458
# (806) 648-1131
# (806) 827-7024
# (806) 827-7123
# (806) 827-7348
# (806) 827-7424
# (806) 827-7468
# (806) 827-7550
# (806) 827-7602
# (940) 552-6946
# (972) 690-9709
# (918) 609-5146
# (580) 443-5779
# (918) 382-9019
# (405) 259-9389
# (918) 224-4181
# (918) 267-5920
# (405) 771-8806
# (405) 392-4000
# (405) 771-3169
# (405) 277-9349
# (918) 299-3947
# (918) 275-8856
# (405) 527-0438
# (405) 527-0296
# (918) 682-5048
# (918) 341-5898
# (410) 939-2995
# (412) 759-4281
# (415) 584-1464
# (417) 206-3401
# (479) 474-3560
# (479) 846-2804
# (479) 965-2404
# (479) 965-7897
# (570) 398-0721
# (601) 371-0924
# (601) 437-8678
# (704) 463-7193
# (704) 489-2684
# (704) 564-3842
# (704) 564-3842
# (704) 588-6086
# (704) 663-7583
# (864) 547-1628
# (803) 432-7096
# (803) 353-0221
# (864) 963-0068
# (803) 773-7204
# (843) 314-3276
# (843) 523-5386
# (864) 287-3293
# (803) 632-1561
# (321) 264-7069
# (323) 932-1483
# (336) 674-9426
# (404) 322-6186
# (404) 377-8004
# (570) 398-0721
# (601) 371-0924
# (601) 437-8678
# (704) 463-7193
# (757) 595-6799
# (800) 922-7821
# (803) 202-0921
# (803) 202-9104
# (803) 222-0387
# (803) 222-0621
# (803) 222-1314
# (803) 222-1508
# (727) 201-9285
# (727) 210-7780
# (727) 216-3301
# (727) 216-3546
# (727) 216-3806
# (727) 216-3806
# (727) 216-3891
# (727) 223-5371
# (727) 223-9219
# (863) 465-1177
# (850) 663-4480
# (386) 774-5575
# (727) 738-4236
# (305) 292-5263
# (321) 773-8558
# (305) 672-9676
# (305) 276-7519
# (386) 672-0365
# (727) 784-3509
# (407) 957-9460
# (850) 639-6390
# (727) 738-6102
# (772) 465-9890
# (850) 639-5725
# (954) 367-2659
# (321) 268-1015
# (352) 621-0854
# (941) 488-5078
# (850) 256-5545
# (305) 295-1335
# (321) 208-7934
# (321) 690-1979
# (321) 639-3115
# (407) 645-3203
# (786) 243-2245
# (301) 390-8065
# (202) 397-4939
# (202) 723-6391
# (202) 248-8818
# (202) 882-7784
# (202) 544-4987
# (202) 484-7509
# (202) 250-2158
# (202) 526-8495
# (202) 561-1052
# (202) 291-7569
# (202) 562-8331
# (202) 562-1166
# (202) 529-5494
# (202) 541-0261
# (202) 388-0372
# (202) 829-7217
# (202) 526-8495
# (202) 561-1052
# (202) 291-7569
# (202) 562-8331
# (202) 562-1166
# (202) 529-5494
# (202) 541-0261
# (202) 388-0372
# (202) 829-7217
# (703) 402-1183
# (703) 402-1183
# (202) 526-8495
# (202) 561-1052
# (202) 291-7569
# (202) 562-8331
# (202) 562-1166
# (202) 529-5494
# (858) 673-0101
# (859) 441-8187
# (859) 581-0588
# (859) 586-7094
# (859) 689-5459
# (859) 746-0108
# (902) 863-4448
# (904) 221-0064
# (904) 794-0023
# (937) 342-1933
# (614) 793-2006
# (740) 642-2121
# (330) 483-6023
# (330) 699-2851
# (740) 355-2502
# (614) 798-4807
# (740) 489-5409
# (740) 503-0084
# (937) 766-5858
# (216) 752-8923
# (937) 642-9710
# (330) 747-1767
# (614) 871-1982
# (513) 932-1365
# (419) 621-7590
# (330) 666-3463
# (234) 248-4098
# (740) 943-3764
# (513) 829-3605
# (937) 696-2518
# (937) 695-0131
# (614) 837-4859
# (330) 702-0307
# (419) 347-1415
# (330) 545-4560
# (336) 272-7056
# (406) 721-6800
# (407) 722-4000
# (414) 212-8635
# (414) 212-8635
# (414) 226-5688
# (414) 228-0411
# (414) 228-0411
# (414) 231-3734
# (616) 608-5276
# (651) 227-1313
# (651) 489-9445
# (660) 857-4410
# (704) 588-7125
# (715) 207-0048
# (715) 207-0167
# (715) 207-0213
# (715) 207-0213
# (336) 272-7056
# (406) 721-6800
# (407) 722-4000
# (414) 212-8635
# (414) 212-8635
# (414) 226-5688
# (414) 228-0411
# (414) 228-0411
# (414) 231-3734
# (866) 898-6444
# (901) 743-4602
# (903) 643-3636
# (903) 834-6318
# (906) 776-9965
# (920) 202-3488
# (920) 202-3488
# (920) 206-0193
# (443) 543-0117
# (443) 922-9714
# (410) 552-0718
# (301) 731-5025
# (240) 264-1992
# (410) 795-0273
# (301) 907-6879
# (301) 868-7684
# (443) 200-3449
# (240) 206-8216
# (240) 206-8216
# (240) 206-8565
# (240) 206-9803
# (240) 207-3265
# (240) 207-3335
# (240) 207-3380
# (240) 207-3493
# (240) 207-3565
# (281) 340-2000
# (281) 340-2000
# (301) 203-0555
# (301) 203-0584
# (301) 203-0638
# (301) 203-0638
# (301) 203-0996
# (301) 203-0996
# (301) 203-1003
# (919) 266-6932
# (919) 816-1614
# (931) 802-5504
# (941) 488-6626
# (941) 488-6626
# (949) 362-6967
# (949) 362-6967
# (954) 486-7705
# (717) 548-4947
# (717) 761-2935
# (570) 676-5348
# (814) 563-4742
# (814) 459-0890
# (814) 272-6955
# (724) 228-1593
# (610) 873-2707
# (814) 765-6139
# (267) 932-8793
# (267) 988-4563
# (267) 988-4563
# (267) 988-4634
# (267) 988-4771
# (267) 999-1112
# (267) 999-1224
# (281) 750-3020
# (301) 678-7210
# (609) 208-0050
# (609) 268-8303
# (609) 353-1030
# (609) 487-3312
# (609) 499-2407
# (609) 522-0673
# (609) 545-8577
# (609) 677-1391
# (609) 730-0710
# (717) 642-6525
# (717) 766-7994
# (814) 942-1927
# (724) 228-4977
# (215) 638-3182
# (610) 351-7412
# (717) 277-7166
# (412) 233-2643
# (714) 283-2061
# (715) 749-0112
# (800) 501-6391
# (801) 944-4810
# (817) 498-9513
# (877) 318-0282
# (888) 277-3332
# (909) 795-6648
# (916) 687-6170
# (971) 279-5749
# (971) 832-8124
# (971) 832-8332
# (972) 461-0761
# (541) 268-1036
# (541) 902-0897
# (541) 482-4374
# (503) 691-9090
# (541) 997-2506
# (662) 798-4169
# (702) 473-9436
# (702) 869-6368
# (714) 283-2061
# (715) 749-0112
# (800) 501-6391
# (801) 944-4810
# (817) 498-9513
# (877) 318-0282
# (661) 746-4667
# (662) 798-4169
# (702) 473-9436
# (702) 869-6368
# (714) 283-2061
# (715) 749-0112
# (800) 501-6391
# (801) 944-4810
# (505) 634-0490
# (505) 632-3883
# (575) 585-8259
# (505) 865-3518
# (575) 377-6039
# (575) 534-1223
# (575) 527-4718
# (505) 579-4512
# (505) 757-6501
# (501) 915-9034
# (505) 237-2187
# (505) 237-2187
# (505) 237-2375
# (505) 242-2846
# (505) 242-2846
# (505) 253-4266
# (505) 253-4349
# (505) 253-4505
# (915) 821-4667
# (928) 729-5555
# (970) 264-4154
# (575) 478-2870
# (575) 478-2870
# (505) 552-7218
# (505) 474-6588
# (505) 466-2556
# (575) 398-6549
# (574) 858-0288
# (575) 218-3015
# (575) 218-3015
# (575) 218-3090
# (575) 218-3090
# (575) 218-3299
# (575) 218-3299
# (575) 218-3722
# (859) 252-2780
# (859) 263-4941
# (864) 261-6982
# (866) 638-2739
# (904) 744-9366
# (910) 449-6715
# (913) 341-0212
# (913) 534-2604
# (914) 476-9167
# (770) 437-0421
# (785) 717-2126
# (800) 779-0902
# (801) 225-5129
# (804) 210-1119
# (804) 214-9952
# (804) 217-7960
# (804) 222-0949
# (608) 255-6083
# (608) 255-6083
# (614) 308-5405
# (614) 308-5405
# (614) 792-6823
# (617) 753-4027
# (650) 604-5342
# (703) 204-0603
# (703) 204-0878
# (804) 210-1119
# (804) 214-9952
# (804) 214-9995
# (804) 217-7960
# (804) 222-0949
# (804) 222-0985
# (804) 222-0985
# (804) 222-3872
# (408) 483-0184
# (415) 844-6273
# (415) 844-6273
# (417) 205-0001
# (417) 205-0013
# (417) 205-0086
# (417) 205-0491
# (417) 205-0670
# (417) 206-0094
# (415) 844-6273
# (415) 844-6273
# (417) 205-0001
# (417) 205-0013
# (417) 205-0086
# (417) 205-0491
# (417) 205-0670
# (417) 206-0094
# (417) 206-0443
# (724) 254-2577
# (731) 287-1347
# (757) 245-0742
# (763) 566-2638
# (765) 287-0911
# (785) 301-2330
# (800) 223-3240
# (800) 472-3737
# (800) 877-5294
# (931) 645-5006
# (660) 886-3530
# (636) 285-0686
# (417) 842-3555
# (417) 452-2384
# (417) 725-9360
# (417) 589-3077
# (573) 468-7398
# (573) 243-3068
# (573) 759-6784
# (601) 684-8619
# (606) 889-8738
# (607) 324-4162
# (608) 564-7304
# (609) 588-9600
# (615) 373-2320
# (615) 373-2320
# (281) 218-8507
# (301) 223-7995
# (301) 223-7995
# (302) 239-3124
# (304) 409-4611
# (309) 203-1238
# (309) 203-1246
# (309) 203-1270
# (309) 203-1382
# (770) 975-7341
# (770) 984-3262
# (770) 984-3262
# (773) 202-0261
# (773) 229-8825
# (773) 229-8825
# (773) 237-1974
# (773) 237-4401
# (773) 238-7162
# (540) 427-1114
# (540) 427-1114
# (540) 989-2956
# (563) 259-0946
# (563) 264-1184
# (563) 264-1184
# (563) 264-2443
# (563) 264-2864
# (602) 218-4312
# (602) 588-0116
# (602) 588-0116
# (605) 853-2414
# (614) 234-0373
# (616) 200-4991
# (616) 200-5356
# (616) 200-5530
# (616) 205-4408
# (707) 542-4092
# (715) 528-5731
# (717) 446-0209
# (727) 868-2014
# (727) 934-1858
# (731) 584-4397
# (732) 927-4073
# (732) 927-4073
# (734) 207-0170
# (936) 449-5032
# (937) 323-0947
# (941) 758-2194
# (941) 761-7810
# (947) 570-1093
# (947) 570-1340
# (947) 570-1366
# (947) 570-1453
# (947) 570-1603
# (586) 207-1638
# (586) 207-1710
# (586) 207-1821
# (586) 207-1846
# (586) 217-5125
# (586) 217-5142
# (586) 217-5246
# (586) 218-4297
# (606) 329-2533
# (606) 622-2240
# (606) 678-4372
# (606) 678-7392
# (606) 784-4934
# (606) 784-7062
# (606) 833-8843
# (606) 833-9054
# (606) 928-4777
# (540) 659-0563
# (540) 843-0233
# (606) 329-2533
# (606) 622-2240
# (606) 678-4372
# (606) 678-7392
# (606) 784-4934
# (606) 784-7062
# (606) 833-8843
# (409) 770-0015
# (508) 825-8325
# (540) 659-0563
# (540) 843-0233
# (606) 329-2533
# (606) 622-2240
# (606) 678-4372
# (606) 678-7392
# (508) 825-8325
# (540) 659-0563
# (540) 843-0233
# (606) 329-2533
# (606) 622-2240
# (606) 678-4372
# (606) 678-7392
# (606) 784-4934
# (406) 373-9201
# (406) 494-4284
# (406) 278-5588
# (406) 323-3299
# (406) 363-4013
# (406) 468-4073
# (406) 353-4146
# (406) 658-2123
# (406) 677-5151
# (406) 763-5027
# (406) 961-4109
# (406) 844-2050
# (406) 723-7807
# (406) 228-4875
# (406) 723-7704
# (406) 854-2150
# (406) 387-4220
# (406) 265-4880
# (651) 578-1419
# (701) 744-3603
# (801) 731-1455
# (801) 796-5870
# (907) 892-7700
# (970) 255-1433
# (406) 373-5443
# (406) 387-5414
# (406) 273-0208
# (651) 578-1419
# (701) 744-3603
# (801) 731-1455
# (801) 796-5870
# (907) 892-7700
# (970) 255-1433
# (406) 373-5443
# (406) 387-5414
# (803) 283-9043
# (803) 285-6273
# (803) 328-2171
# (803) 548-1321
# (803) 980-5700
# (803) 980-8447
# (803) 980-8447
# (804) 739-4657
# (810) 787-7743
# (410) 305-4126
# (410) 305-4126
# (413) 443-9250
# (413) 527-0650
# (434) 476-9683
# (442) 761-4888
# (443) 736-7551
# (502) 589-6728
# (503) 372-6302
# (904) 277-8806
# (905) 538-5812
# (910) 201-1432
# (910) 201-1566
# (910) 201-1695
# (910) 201-4111
# (910) 201-4245
# (910) 201-4628
# (910) 205-0100
# (252) 356-1306
# (919) 719-9171
# (704) 774-1627
# (336) 719-2465
# (252) 756-4136
# (828) 466-0214
# (704) 764-7624
# (828) 758-0316
# (918) 693-6828
# (919) 479-2000
# (928) 284-0401
# (931) 484-1886
# (940) 668-8622
# (954) 384-8110
# (978) 203-0235
# (978) 203-0246
# (978) 203-0531
# (773) 284-7374
# (774) 202-0059
# (774) 202-0108
# (774) 202-0953
# (774) 202-2373
# (774) 202-2785
# (774) 202-3351
# (774) 202-3482
# (774) 202-4399
# (508) 362-8425
# (781) 936-8284
# (508) 999-5460
# (978) 537-5629
# (508) 224-3937
# (508) 255-8783
# (413) 499-5553
# (413) 499-5553
# (508) 339-8453
# (319) 331-5049
# (334) 271-2935
# (339) 244-4678
# (339) 244-4710
# (339) 244-4744
# (339) 440-4148
# (339) 440-4461
# (339) 440-4831
